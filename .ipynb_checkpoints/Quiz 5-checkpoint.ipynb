# %% [markdown]
# # Quiz 5
# Please follow the directions below, in which you will extract data from an off-line source and migrate it into a normalized SQLite database. Points will be awarded as indicated. Note: later steps depend on earlier steps, so you should check your work as you go along.
#
# __All required cells have been provided. You only need to edit the ones that have placeholder phrases like YOUR CODE HERE.__
#
# This quiz is open book. You may use whatever documentation you like (even Google or past assignments in the course) but **you may not consult another person during the quiz** without the instructor's permission. That includes sharing code with your classmates, which is obviously not allowed.
#
# __Finally, use comments to document what you are doing with each block of code. Poorly documented code will be penalized accordingly.__

# %% [markdown]
# ## 1. (4 points) Import/Load all required packages.
# Import `pandas`, `sqlite3`, and the `parse_course_spec()` function from [`coursedata-util.py`](coursedata_util.py). (Hint: you may want to take a look at how we imported custom module code in the Movies Tonight Part 5 demo.) Then load the `sql` Jupyter extention needed for `%sql` magic.

# %%
import pandas as pd
import sqlite3
from coursedata_util import parse_course_spec
# %load_ext sql

# %% [markdown]
# ## 2. (1 point) Create a SQLite database named `FairfieldCoursesFall2017.db`.

# %%
# %sql sqlite:///FairfieldCoursesFall2017.db
# Out:
# 'Connected: None@FairfieldCoursesFall2017.db'

# %% [markdown]
# ## 3. (8 points) Study the source data and design your database.
# The [`CourseScheduleScrape.txt` file](CourseScheduleScrape.txt) located in this folder was *scraped* directly from the PDF of the [Fall 2016 Schedule of Courses](Fall2015_course_booklet.pdf) booklet. The code cell below *parses* each line of the file into a `list` of `dict`s called `course_specs`. The result looks a lot like [JSON-formatted data](https://www.ibm.com/support/knowledgecenter/en/STXNRM_3.10.2/coss.doc/managerapi1128.html) commonly returned by ReSTful web services. You will need to extract the data into tables in a SQLite database.

# %%
# DO NOT EDIT THIS CELL
course_specs = []
for spec in open("CourseScheduleScrape.txt").read().splitlines():
    course_specs.append(parse_course_spec(spec))
course_specs
# Out:
# [{'CRN': '76407',
#   'CatalogID': 'AS0200',
#   'Credits': '3',
#   'Instructor': 'Bayers P',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Roots of American Culture'},
#  {'CRN': '76513',
#   'CatalogID': 'AS0400',
#   'Credits': '3',
#   'Instructor': 'Garvey J',
#   'Section': '01',
#   'Tags': ['By Permission'],
#   'Timecodes': ['W 0630-0830pm'],
#   'Title': 'Critical Issues/Amer Studies'},
#  {'CRN': '76934',
#   'CatalogID': 'AS0488',
#   'Credits': '3',
#   'Instructor': 'Bayers P',
#   'Section': '01',
#   'Tags': ['By Permission'],
#   'Timecodes': ['M 0630-0830pm'],
#   'Title': 'Frontier in American Culture'},
#  {'CRN': '76935',
#   'CatalogID': 'ASEN0490',
#   'Credits': '3',
#   'Instructor': 'Lopez E',
#   'Section': '01',
#   'Tags': ['By Permission'],
#   'Timecodes': ['T 0545-0745pm'],
#   'Title': 'Contemporary American Memoir'},
#  {'CRN': '75478',
#   'CatalogID': 'AY0010',
#   'Credits': '3',
#   'Instructor': 'Lacy S',
#   'Section': 'C01',
#   'Tags': ['CRNST', 'WDiv'],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Intro to Four-Field Anthropo'},
#  {'CRN': '75479',
#   'CatalogID': 'AY0010',
#   'Credits': '3',
#   'Instructor': 'Lacy S',
#   'Section': 'C02',
#   'Tags': ['CRNST', 'WDiv'],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Intro to Four-Field Anthropo'},
#  {'CRN': '75752',
#   'CatalogID': 'AY0052',
#   'Credits': '3',
#   'Instructor': 'Crawford D',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TR 0630-0745pm'],
#   'Title': 'Culture and Political Economy'},
#  {'CRN': '76300',
#   'CatalogID': 'AY0052',
#   'Credits': '3',
#   'Instructor': 'Wilson J',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Culture and Political Economy'},
#  {'CRN': '75297',
#   'CatalogID': 'AY0110',
#   'Credits': '3',
#   'Instructor': 'Wilson J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'Biological Anthropology'},
#  {'CRN': '75728',
#   'CatalogID': 'AY0111',
#   'Credits': '3',
#   'Instructor': 'Crawford D',
#   'Section': 'A',
#   'Tags': ['WDiv'],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Cultural Anthropology'},
#  {'CRN': '76753',
#   'CatalogID': 'AY0111',
#   'Credits': '3',
#   'Instructor': 'Wessler S',
#   'Section': 'B',
#   'Tags': ['WDiv'],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Cultural Anthropology'},
#  {'CRN': '76758',
#   'CatalogID': 'AY0115',
#   'Credits': '3',
#   'Instructor': 'Aronsen G',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0630-0900pm'],
#   'Title': 'Biomedical Anthropology'},
#  {'CRN': '76303',
#   'CatalogID': 'AY0152',
#   'Credits': '3',
#   'Instructor': 'Crawford D',
#   'Section': 'A',
#   'Tags': ['WDiv', 'ResColl'],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Islamic Societies & Cultures'},
#  {'CRN': '76754',
#   'CatalogID': 'AY0168',
#   'Credits': '3',
#   'Instructor': 'Wessler S',
#   'Section': 'A',
#   'Tags': ['WDiv'],
#   'Timecodes': ['TF 0330-0445pm'],
#   'Title': 'Women & Men: Anthro of Gender'},
#  {'CRN': '75333',
#   'CatalogID': 'AE0262',
#   'Credits': '3',
#   'Instructor': 'Liftig R',
#   'Section': 'A',
#   'Tags': ['USDiv'],
#   'Timecodes': ['W 0200-0430pm'],
#   'Title': 'Ethics and the Community'},
#  {'CRN': '75233',
#   'CatalogID': 'AE0265',
#   'Credits': '3',
#   'Instructor': 'Liftig R',
#   'Section': 'A',
#   'Tags': ['USDiv'],
#   'Timecodes': ['TR 0500-0615pm'],
#   'Title': 'Ethics in Education'},
#  {'CRN': '75282',
#   'CatalogID': 'AE0276',
#   'Credits': '3',
#   'Instructor': 'Day R',
#   'Section': 'A',
#   'Tags': ['WDiv'],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Ethical DimensGlobal BusPolicy'},
#  {'CRN': '76234',
#   'CatalogID': 'AE0281',
#   'Credits': '3',
#   'Instructor': 'Butler B',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0630-0900pm'],
#   'Title': 'Ethics of Communications'},
#  {'CRN': '76826',
#   'CatalogID': 'AE0284',
#   'Credits': '3',
#   'Instructor': 'Brown D',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['WF 0800-0915am'],
#   'Title': 'Environmental Ethics'},
#  {'CRN': '75125',
#   'CatalogID': 'AE0284',
#   'Credits': '3',
#   'Instructor': 'Brown D',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['R 0630-0900pm'],
#   'Title': 'Environmental Ethics'},
#  {'CRN': '75001',
#   'CatalogID': 'AE0285',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MW 0500-0615pm'],
#   'Title': 'Ethics of Health Care'},
#  {'CRN': '75002',
#   'CatalogID': 'AE0291',
#   'Credits': '3',
#   'Instructor': 'Schmidt D',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Business Ethics'},
#  {'CRN': '75003',
#   'CatalogID': 'AE0291',
#   'Credits': '3',
#   'Instructor': 'Sticca-Conrod L',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['Online'],
#   'Title': 'Business Ethics'},
#  {'CRN': '75070',
#   'CatalogID': 'AE0291',
#   'Credits': '3',
#   'Instructor': 'Sticca-Conrod L',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['Online'],
#   'Title': 'Business Ethics'},
#  {'CRN': '75308',
#   'CatalogID': 'AE0291',
#   'Credits': '3',
#   'Instructor': 'Ventrella S',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['T 0630-0900pm'],
#   'Title': 'Business Ethics'},
#  {'CRN': '75313',
#   'CatalogID': 'AE0291',
#   'Credits': '3',
#   'Instructor': 'Yoder J',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['W 0630-0900pm'],
#   'Title': 'Business Ethics'},
#  {'CRN': '76827',
#   'CatalogID': 'AE0291',
#   'Credits': '3',
#   'Instructor': 'Schmidt N',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Business Ethics'},
#  {'CRN': '76828',
#   'CatalogID': 'AE0291',
#   'Credits': '3',
#   'Instructor': 'Schmidt D',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'Business Ethics'},
#  {'CRN': '75344',
#   'CatalogID': 'AR0110',
#   'Credits': '3',
#   'Instructor': 'Douda A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MW 0300-0445pm'],
#   'Title': 'Elementary Arabic I'},
#  {'CRN': '75402',
#   'CatalogID': 'AR0210',
#   'Credits': '3',
#   'Instructor': 'Douda A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MW 0500-0645pm'],
#   'Title': 'Intermediate Arabic I'},
#  {'CRN': '75745',
#   'CatalogID': 'AR0381',
#   'Credits': '3',
#   'Instructor': 'Douda A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0100-0200pm'],
#   'Title': 'Coordinating Seminar'},
#  {'CRN': '76861',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Poe A',
#   'Section': '01',
#   'Tags': [],
#   'Timecodes': ['Online'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '75165',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Schwab K',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0120pm', 'W 1200-1250pm'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '76861',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Poe A',
#   'Section': '01',
#   'Tags': [],
#   'Timecodes': ['Online'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '75165',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Schwab K',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0120pm', 'W 1200-1250pm'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '75166',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Eliasoph P',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '75559',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Rose M',
#   'Section': 'C01',
#   'Tags': ['CRNST'],
#   'Timecodes': ['TWF 1100-1150am'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '75167',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Eliasoph P',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '75168',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Eliasoph P',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['T 0630-0900pm'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '75432',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Rose M',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0120pm', 'W 0100-0150pm'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '76860',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Schwab K',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '76317',
#   'CatalogID': 'AH0013',
#   'Credits': '3',
#   'Instructor': 'Covaci I',
#   'Section': 'A',
#   'Tags': ['WDiv'],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Art/ Africa,Caribbean,Americas'},
#  {'CRN': '76318',
#   'CatalogID': 'AH0014',
#   'Credits': '3',
#   'Instructor': 'Covaci I',
#   'Section': 'A',
#   'Tags': ['WDiv'],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Art of Asia'},
#  {'CRN': '76862',
#   'CatalogID': 'AH0112',
#   'Credits': '3',
#   'Instructor': 'Rose M',
#   'Section': 'A',
#   'Tags': ['JUHAN'],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Etruscan & Roman Art & Archaeo'},
#  {'CRN': '76863',
#   'CatalogID': 'AH0130',
#   'Credits': '3',
#   'Instructor': 'Eliasoph P',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0200-0430pm'],
#   'Title': 'Renaissance Art in Italy'},
#  {'CRN': '76864',
#   'CatalogID': 'AH0172',
#   'Credits': '3',
#   'Instructor': 'Cesiro L',
#   'Section': 'A',
#   'Tags': ['ResColl'],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'History of Photography'},
#  {'CRN': '76865',
#   'CatalogID': 'AH0290B',
#   'Credits': '3',
#   'Instructor': 'Schwab K',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Topics: Hair in Classical Wrld'},
#  {'CRN': '75456',
#   'CatalogID': 'AN0310',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Asian Studies Seminar'},
#  {'CRN': '75944',
#   'CatalogID': 'BI0015',
#   'Credits': '3',
#   'Instructor': 'Blough C',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'General Biology I'},
#  {'CRN': '76788',
#   'CatalogID': 'BI0015',
#   'Credits': '3',
#   'Instructor': 'Blough C',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'General Biology I'},
#  {'CRN': '75219',
#   'CatalogID': 'BI0018',
#   'Credits': '3',
#   'Instructor': 'Dutta I',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Human Biology: Form & Function'},
#  {'CRN': '75304',
#   'CatalogID': 'BI0018',
#   'Credits': '3',
#   'Instructor': 'Dutta I',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Human Biology: Form & Function'},
#  {'CRN': '76460',
#   'CatalogID': 'BI0070',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0800-0915am'],
#   'Title': 'Science, Technology & Society'},
#  {'CRN': '76461',
#   'CatalogID': 'BI0070',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Science, Technology & Society'},
#  {'CRN': '76287',
#   'CatalogID': 'BI0073',
#   'Credits': '3',
#   'Instructor': 'Vernarelli J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Contemp Nutr:Food for Thought'},
#  {'CRN': '76789',
#   'CatalogID': 'BI0074',
#   'Credits': '3',
#   'Instructor': 'Klug J',
#   'Section': 'A',
#   'Tags': ['Water'],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Biology of Food'},
#  {'CRN': '76790',
#   'CatalogID': 'BI0075',
#   'Credits': '3',
#   'Instructor': 'Choly J',
#   'Section': 'A',
#   'Tags': ['ResColl', 'Water'],
#   'Timecodes': ['MW 0630-0745pm'],
#   'Title': 'Ecology and Society'},
#  {'CRN': '76235',
#   'CatalogID': 'BI0078',
#   'Credits': '3',
#   'Instructor': 'Ortman B',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TR 0500-0615pm'],
#   'Title': 'Introduction to Marine Science'},
#  {'CRN': '76236',
#   'CatalogID': 'BI0078',
#   'Credits': '3',
#   'Instructor': 'Ortman B',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TR 0630-0745pm'],
#   'Title': 'Introduction to Marine Science'},
#  {'CRN': '76791',
#   'CatalogID': 'BI0096',
#   'Credits': '3',
#   'Instructor': 'Sauer G',
#   'Section': 'A',
#   'Tags': ['ResColl'],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'God and Modern Biology'},
#  {'CRN': '76422',
#   'CatalogID': 'BI0107',
#   'Credits': '4',
#   'Instructor': 'Earls C',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Human Anatomy & Physiology'},
#  {'CRN': '75868',
#   'CatalogID': 'BI0107',
#   'Credits': '4',
#   'Instructor': 'Earls C',
#   'Section': 'A-C',
#   'Tags': ['CRNST'],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Human Anatomy & Physiology'},
#  {'CRN': '76423',
#   'CatalogID': 'BI0107',
#   'Credits': '4',
#   'Instructor': 'DeCristofaro A',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Human Anatomy & Physiology'},
#  {'CRN': '76120',
#   'CatalogID': 'BI0107',
#   'Credits': '4',
#   'Instructor': 'DeCristofaro A',
#   'Section': 'B-C',
#   'Tags': ['CRNST'],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Human Anatomy & Physiology'},
#  {'CRN': '75617',
#   'CatalogID': 'BI0107L',
#   'Credits': '0',
#   'Instructor': 'Earls C',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0100-0350pm'],
#   'Title': 'Human Anatomy & Physiology Lab'},
#  {'CRN': '75621',
#   'CatalogID': 'BI0107L',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['T 0900-1150am'],
#   'Title': 'Human Anatomy & Physiology Lab'},
#  {'CRN': '75646',
#   'CatalogID': 'BI0107L',
#   'Credits': '0',
#   'Instructor': 'DeCristofaro A',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['W 0830-1120am'],
#   'Title': 'Human Anatomy & Physiology Lab'},
#  {'CRN': '75647',
#   'CatalogID': 'BI0107L',
#   'Credits': '0',
#   'Instructor': 'DeCristofaro A',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['W 1230-0320pm'],
#   'Title': 'Human Anatomy & Physiology Lab'},
#  {'CRN': '75653',
#   'CatalogID': 'BI0107L',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['W 0530-0820pm'],
#   'Title': 'Human Anatomy & Physiology Lab'},
#  {'CRN': '76060',
#   'CatalogID': 'BI0107L',
#   'Credits': '0',
#   'Instructor': 'Earls C',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['R 0100-0350pm'],
#   'Title': 'Human Anatomy & Physiology Lab'},
#  {'CRN': '76462',
#   'CatalogID': 'BI0107L',
#   'Credits': '0',
#   'Instructor': 'Earls C',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['F 1000-1250pm'],
#   'Title': 'Human Anatomy & Physiology Lab'},
#  {'CRN': '75279',
#   'CatalogID': 'BI0151',
#   'Credits': '4',
#   'Instructor': 'Zavras E',
#   'Section': 'A',
#   'Tags': ['NS Only'],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Elements of Microbiology'},
#  {'CRN': '75662',
#   'CatalogID': 'BI0151L',
#   'Credits': '0',
#   'Instructor': 'Zavras E',
#   'Section': 'A',
#   'Tags': ['NS Only'],
#   'Timecodes': ['M 0200-0450pm'],
#   'Title': 'Elements of Microbiology Lab'},
#  {'CRN': '75663',
#   'CatalogID': 'BI0151L',
#   'Credits': '0',
#   'Instructor': 'Zavras E',
#   'Section': 'B',
#   'Tags': ['NS Only'],
#   'Timecodes': ['T 0200-0450pm'],
#   'Title': 'Elements of Microbiology Lab'},
#  {'CRN': '75664',
#   'CatalogID': 'BI0151L',
#   'Credits': '0',
#   'Instructor': 'Zavras E',
#   'Section': 'C',
#   'Tags': ['NS Only'],
#   'Timecodes': ['R 0200-0450pm'],
#   'Title': 'Elements of Microbiology Lab'},
#  {'CRN': '76424',
#   'CatalogID': 'BI0170',
#   'Credits': '4',
#   'Instructor': 'Fernandez A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'General Biology I'},
#  {'CRN': '75468',
#   'CatalogID': 'BI0170',
#   'Credits': '4',
#   'Instructor': 'Fernandez A',
#   'Section': 'A-C',
#   'Tags': ['CRNST'],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'General Biology I'},
#  {'CRN': '76425',
#   'CatalogID': 'BI0170',
#   'Credits': '4',
#   'Instructor': 'Fernandez A',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'General Biology I'},
#  {'CRN': '75212',
#   'CatalogID': 'BI0170',
#   'Credits': '4',
#   'Instructor': 'Fernandez A',
#   'Section': 'B-C',
#   'Tags': ['CRNST'],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'General Biology I'},
#  {'CRN': '75665',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'Braun P',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0200-0450pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75666',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'Biardi L',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['M 0200-0450pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75667',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'Andersen C',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['T 0200-0450pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75668',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'Phelan S',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['T 0200-0450pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75669',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'Andersen C',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['W 0200-0450pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75670',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['W 0200-0450pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75671',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['W 0530-0820pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75672',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'Braun P',
#   'Section': 'H',
#   'Tags': [],
#   'Timecodes': ['R 0200-0450pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75673',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'I',
#   'Tags': [],
#   'Timecodes': ['R 0200-0450pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75674',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0300-0350pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75675',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['T 0400-0450pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75677',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['T 0500-0550pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75679',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['T 0600-0650pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75680',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['W 0300-0330pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75681',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['W 0400-0450pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75682',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['W 0500-0550pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75683',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'H',
#   'Tags': [],
#   'Timecodes': ['W 0600-0650pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75684',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'I',
#   'Tags': [],
#   'Timecodes': ['R 0300-0350pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75685',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'J',
#   'Tags': [],
#   'Timecodes': ['R 0400-0450pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75686',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'K',
#   'Tags': [],
#   'Timecodes': ['R 0500-0550pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75687',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'L',
#   'Tags': [],
#   'Timecodes': ['R 0600-0650pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75250',
#   'CatalogID': 'BI0172',
#   'Credits': '4',
#   'Instructor': 'Biardi J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'General Biology III'},
#  {'CRN': '75688',
#   'CatalogID': 'BI0172L',
#   'Credits': '0',
#   'Instructor': 'Biardi J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0200-0450pm'],
#   'Title': 'General Biology III Lab'},
#  {'CRN': '75689',
#   'CatalogID': 'BI0172L',
#   'Credits': '0',
#   'Instructor': 'Osier T',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['T 0200-0450pm'],
#   'Title': 'General Biology III Lab'},
#  {'CRN': '75690',
#   'CatalogID': 'BI0172L',
#   'Credits': '0',
#   'Instructor': 'Osier T',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['W 0200-0450pm'],
#   'Title': 'General Biology III Lab'},
#  {'CRN': '75691',
#   'CatalogID': 'BI0172L',
#   'Credits': '0',
#   'Instructor': 'Ansari J',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['W 0200-0450pm'],
#   'Title': 'General Biology III Lab'},
#  {'CRN': '76430',
#   'CatalogID': 'BI0172L',
#   'Credits': '0',
#   'Instructor': 'Brousseau D',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['R 0200-0450pm'],
#   'Title': 'General Biology III Lab'},
#  {'CRN': '75695',
#   'CatalogID': 'BI0201',
#   'Credits': '1',
#   'Instructor': 'Gerry S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['By Arrangement'],
#   'Title': 'Biology Teaching Practicum'},
#  {'CRN': '75758',
#   'CatalogID': 'BI0202',
#   'Credits': '1',
#   'Instructor': 'Gerry S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['By Arrangement'],
#   'Title': 'Biology Teaching Practicum'},
#  {'CRN': '75759',
#   'CatalogID': 'BI0203',
#   'Credits': '1',
#   'Instructor': 'Gerry S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['By Arrangement'],
#   'Title': 'Biology Teaching Practicum'},
#  {'CRN': '76237',
#   'CatalogID': 'BI0204',
#   'Credits': '1',
#   'Instructor': 'Gerry S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['By Arrangement'],
#   'Title': 'Biology Teaching Practicum'},
#  {'CRN': '76238',
#   'CatalogID': 'BI0205',
#   'Credits': '1',
#   'Instructor': 'Gerry S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['By Arrangement'],
#   'Title': 'Biology Teaching Practicum'},
#  {'CRN': '76792',
#   'CatalogID': 'BI0206',
#   'Credits': '1',
#   'Instructor': 'Gerry S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['By Arrangement'],
#   'Title': 'Biology Teaching Practicum'},
#  {'CRN': '76793',
#   'CatalogID': 'BI0262',
#   'Credits': '4',
#   'Instructor': 'Gerry S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Human Physiology'},
#  {'CRN': '76794',
#   'CatalogID': 'BI0262L',
#   'Credits': '0',
#   'Instructor': 'Gerry S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0200-0450pm'],
#   'Title': 'Human Physiology Lab'},
#  {'CRN': '75066',
#   'CatalogID': 'BI0296',
#   'Credits': '3',
#   'Instructor': 'Harriott O',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['By Arrangement'],
#   'Title': 'Special Topics in Biology'},
#  {'CRN': '76798',
#   'CatalogID': 'BI0317',
#   'Credits': '4',
#   'Instructor': 'Vernarelli J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Epidemiology & Applied Biostat'},
#  {'CRN': '76239',
#   'CatalogID': 'BI0324',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Biochemistry I'},
#  {'CRN': '76795',
#   'CatalogID': 'BI0324L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0200-0450pm'],
#   'Title': 'Biochemistry I Lab'},
#  {'CRN': '76796',
#   'CatalogID': 'BI0325',
#   'Credits': '3',
#   'Instructor': 'Sauer G',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Biochemistry II'},
#  {'CRN': '76797',
#   'CatalogID': 'BI0325L',
#   'Credits': '1',
#   'Instructor': 'Sauer G',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0200-0450pm'],
#   'Title': 'Biochemistry II Lab'},
#  {'CRN': '75415',
#   'CatalogID': 'BI0352',
#   'Credits': '4',
#   'Instructor': 'Harriott O',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Fundamentals of Microbiology'},
#  {'CRN': '75694',
#   'CatalogID': 'BI0352L',
#   'Credits': '0',
#   'Instructor': 'Harriott O',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0930-1220pm'],
#   'Title': 'Fund. of Microbiology Lab'},
#  {'CRN': '75575',
#   'CatalogID': 'BI0354',
#   'Credits': '3',
#   'Instructor': 'Braun P',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Molecular Biology'},
#  {'CRN': '75280',
#   'CatalogID': 'BI0362',
#   'Credits': '4',
#   'Instructor': 'Brousseau D',
#   'Section': 'A',
#   'Tags': ['Water'],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Marine Invertebrate Zoology'},
#  {'CRN': '75692',
#   'CatalogID': 'BI0362L',
#   'Credits': '0',
#   'Instructor': 'Brousseau D',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0200-0450pm'],
#   'Title': 'Marine Invertebrate Zoolgy Lab'},
#  {'CRN': '75450',
#   'CatalogID': 'BI0365',
#   'Credits': '4',
#   'Instructor': 'Byun S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Evolutionary Biology'},
#  {'CRN': '75693',
#   'CatalogID': 'BI0365L',
#   'Credits': '0',
#   'Instructor': 'Byun S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0100-0350pm'],
#   'Title': 'Evolutionary Biology Lab'},
#  {'CRN': '76800',
#   'CatalogID': 'BI0381B',
#   'Credits': '3',
#   'Instructor': 'Phelan S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Sem: Molec Mech /Human Disease'},
#  {'CRN': '76801',
#   'CatalogID': 'BI0381D',
#   'Credits': '3',
#   'Instructor': 'Andersen C',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Sem: Nutritional Epigenetics'},
#  {'CRN': '75416',
#   'CatalogID': 'BI0391',
#   'Credits': '3',
#   'Instructor': 'Biardi J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Biology Research I'},
#  {'CRN': '75417',
#   'CatalogID': 'BI0392',
#   'Credits': '2',
#   'Instructor': 'Biardi J',
#   'Section': 'A2',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Biology Research II'},
#  {'CRN': '76434',
#   'CatalogID': 'BI0392',
#   'Credits': '3',
#   'Instructor': 'Biardi J',
#   'Section': 'A3',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Biology Research II'},
#  {'CRN': '75418',
#   'CatalogID': 'BI0393',
#   'Credits': '3',
#   'Instructor': 'Biardi J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Biology Research III'},
#  {'CRN': '76802',
#   'CatalogID': 'BI0394',
#   'Credits': '3',
#   'Instructor': 'Biardi J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Biology Research IV'},
#  {'CRN': '76783',
#   'CatalogID': 'CH0007',
#   'Credits': '3',
#   'Instructor': 'Harper-Leatherman A',
#   'Section': 'A',
#   'Tags': ['ResColl'],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Intro to Forensic Science'},
#  {'CRN': '76100',
#   'CatalogID': 'CH0010',
#   'Credits': '3',
#   'Instructor': 'OÕConnell E',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Chemistry: Sights & Insights'},
#  {'CRN': '75152',
#   'CatalogID': 'CH0083',
#   'Credits': '3',
#   'Instructor': 'Bethray S',
#   'Section': 'A',
#   'Tags': ['Water'],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Survey of Chemistry'},
#  {'CRN': '75293',
#   'CatalogID': 'CH0084',
#   'Credits': '3',
#   'Instructor': 'Reilly-Wiedow E',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Gen Chem for Health Science'},
#  {'CRN': '75589',
#   'CatalogID': 'CH0084L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0900-1150am'],
#   'Title': 'Gen Chem Health Science Lab'},
#  {'CRN': '75590',
#   'CatalogID': 'CH0084L',
#   'Credits': '1',
#   'Instructor': 'Reilly-Wiedow E',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['T 0900-1150am'],
#   'Title': 'Gen Chem Health Science Lab'},
#  {'CRN': '75591',
#   'CatalogID': 'CH0084L',
#   'Credits': '1',
#   'Instructor': 'Reilly-Wiedow E',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['W 0900-1150am'],
#   'Title': 'Gen Chem Health Science Lab'},
#  {'CRN': '76245',
#   'CatalogID': 'CH0084L',
#   'Credits': '1',
#   'Instructor': 'Reilly-Wiedow E',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['R 0900-1150am'],
#   'Title': 'Gen Chem Health Science Lab'},
#  {'CRN': '75588',
#   'CatalogID': 'CH0085',
#   'Credits': '3',
#   'Instructor': 'Steffen L',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Chemistry,Energy & Environment'},
#  {'CRN': '75457',
#   'CatalogID': 'CH0086',
#   'Credits': '3',
#   'Instructor': 'Sobczynski D',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TR 0500-0615pm'],
#   'Title': 'Chemistry and Art'},
#  {'CRN': '75600',
#   'CatalogID': 'CH0111',
#   'Credits': '3',
#   'Instructor': 'STAFF EG Only',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0600-0900pm'],
#   'Title': 'General Chemistry I'},
#  {'CRN': '75601',
#   'CatalogID': 'CH0111',
#   'Credits': '3',
#   'Instructor': 'Fischer R',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0145pm', 'W 1200-1250pm'],
#   'Title': 'General Chemistry I'},
#  {'CRN': '75602',
#   'CatalogID': 'CH0111',
#   'Credits': '3',
#   'Instructor': 'Kubasik M',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['R 0200-0250pm', 'TF 0830-0920am', 'W 0800-0850am'],
#   'Title': 'General Chemistry I'},
#  {'CRN': '75603',
#   'CatalogID': 'CH0111',
#   'Credits': '3',
#   'Instructor': 'Weddle G',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['M 1100-1150am', 'TWF 1100-1150am'],
#   'Title': 'General Chemistry I'},
#  {'CRN': '75604',
#   'CatalogID': 'CH0111',
#   'Credits': '3',
#   'Instructor': 'Weddle G',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['M 0930-1020am', 'TWF 0930-1020am'],
#   'Title': 'General Chemistry I'},
#  {'CRN': '75718',
#   'CatalogID': 'CH0111',
#   'Credits': '3',
#   'Instructor': 'Fischer R',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm', 'W 1000-1050am'],
#   'Title': 'General Chemistry I'},
#  {'CRN': '75578',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 1230-0320pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75579',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['M 0500-0750pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75580',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'Weddle G',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['T 1230-0320pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75581',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'Fischer S',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['T 0500-0750pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75582',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'Fischer S',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['W 0100-0350pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75583',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['W 0500-0750pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75584',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'Harper J',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['R 1230-0320pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75585',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'H',
#   'Tags': [],
#   'Timecodes': ['R 0500-0750pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75586',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'I',
#   'Tags': [],
#   'Timecodes': ['F 0900-1150am'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75587',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'J',
#   'Tags': [],
#   'Timecodes': ['F 1230-0320pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75061',
#   'CatalogID': 'CH0211',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am', 'W 0800-0850am'],
#   'Title': 'Organic Chemistry I'},
#  {'CRN': '75062',
#   'CatalogID': 'CH0211',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am', 'W 1000-1050am'],
#   'Title': 'Organic Chemistry I'},
#  {'CRN': '75473',
#   'CatalogID': 'CH0211',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am', 'W 0900-0950am'],
#   'Title': 'Organic Chemistry I'},
#  {'CRN': '75592',
#   'CatalogID': 'CH0211L',
#   'Credits': '1',
#   'Instructor': 'Lloyd J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 1230-0430pm'],
#   'Title': 'Organic Chemistry I Lab'},
#  {'CRN': '75593',
#   'CatalogID': 'CH0211L',
#   'Credits': '1',
#   'Instructor': 'Schirmann P',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['T 1230-0430pm'],
#   'Title': 'Organic Chemistry I Lab'},
#  {'CRN': '75594',
#   'CatalogID': 'CH0211L',
#   'Credits': '1',
#   'Instructor': 'Lloyd J',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['W 0100-0500pm'],
#   'Title': 'Organic Chemistry I Lab'},
#  {'CRN': '75595',
#   'CatalogID': 'CH0211L',
#   'Credits': '1',
#   'Instructor': 'OÕConnell E',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['R 1230-0430pm'],
#   'Title': 'Organic Chemistry I Lab'},
#  {'CRN': '75596',
#   'CatalogID': 'CH0211L',
#   'Credits': '1',
#   'Instructor': 'Schirmann P',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['R 0500-0850pm'],
#   'Title': 'Organic Chemistry I Lab'},
#  {'CRN': '75597',
#   'CatalogID': 'CH0211L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['F 1230-0430pm'],
#   'Title': 'Organic Chemistry I Lab'},
#  {'CRN': '75063',
#   'CatalogID': 'CH0261',
#   'Credits': '3',
#   'Instructor': 'Kubasik M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TWF 1100-1150am'],
#   'Title': 'Physical Chemistry I'},
#  {'CRN': '75598',
#   'CatalogID': 'CH0261L',
#   'Credits': '1',
#   'Instructor': 'Kubasik M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0200-0450pm'],
#   'Title': 'Physical Chemistry I Lab'},
#  {'CRN': '76246',
#   'CatalogID': 'CH0324',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Biochemistry I'},
#  {'CRN': '76784',
#   'CatalogID': 'CH0324L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0200-0450pm'],
#   'Title': 'Biochemistry I Lab'},
#  {'CRN': '76785',
#   'CatalogID': 'CH0325',
#   'Credits': '3',
#   'Instructor': 'Sauer G',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Biochemistry II'},
#  {'CRN': '76786',
#   'CatalogID': 'CH0325L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0200-0450pm'],
#   'Title': 'Biochemistry II Lab'},
#  {'CRN': '75294',
#   'CatalogID': 'CH0326',
#   'Credits': '3',
#   'Instructor': 'Harper-Leatherman A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Chemical Instrumentation'},
#  {'CRN': '75348',
#   'CatalogID': 'CI0110',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TWF 0200-0250pm'],
#   'Title': 'Elementary Chinese I'},
#  {'CRN': '75349',
#   'CatalogID': 'CI0210',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0130pm', 'W 0100-0150pm'],
#   'Title': 'Intermediate Chinese I'},
#  {'CRN': '76773',
#   'CatalogID': 'CL0106',
#   'Credits': '3',
#   'Instructor': 'Rosivach V',
#   'Section': 'A',
#   'Tags': ['English Core'],
#   'Timecodes': ['W 0630-0900pm'],
#   'Title': 'MasterpiecesGrk Lit/Eng Transl'},
#  {'CRN': '76242',
#   'CatalogID': 'CL0116',
#   'Credits': '3',
#   'Instructor': 'Ruffini G',
#   'Section': 'A',
#   'Tags': ['History Core'],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Roman Civilization'},
#  {'CRN': '76243',
#   'CatalogID': 'CL0116',
#   'Credits': '3',
#   'Instructor': 'Ruffini G',
#   'Section': 'B',
#   'Tags': ['History Core'],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Roman Civilization'},
#  {'CRN': '75134',
#   'CatalogID': 'CO0100',
#   'Credits': '3',
#   'Instructor': 'Ryan M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TWF 1100-1150am'],
#   'Title': 'Human Communication Theories'},
#  {'CRN': '75148',
#   'CatalogID': 'CO0100',
#   'Credits': '3',
#   'Instructor': 'Brennan N',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Human Communication Theories'},
#  {'CRN': '75133',
#   'CatalogID': 'CO0100',
#   'Credits': '3',
#   'Instructor': 'Ryan M',
#   'Section': 'C01',
#   'Tags': ['CRNST'],
#   'Timecodes': ['TF 0930-1020am', 'W 0900-0950am'],
#   'Title': 'Human Communication Theories'},
#  {'CRN': '75721',
#   'CatalogID': 'CO0100',
#   'Credits': '3',
#   'Instructor': 'Brennan N',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['TF 0330-0445pm'],
#   'Title': 'Human Communication Theories'},
#  {'CRN': '75135',
#   'CatalogID': 'CO0101',
#   'Credits': '3',
#   'Instructor': 'DÕAmico C',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Argument and Advocacy'},
#  {'CRN': '75136',
#   'CatalogID': 'CO0101',
#   'Credits': '3',
#   'Instructor': 'DÕAmico C',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Argument and Advocacy'},
#  {'CRN': '75190',
#   'CatalogID': 'CO0101',
#   'Credits': '3',
#   'Instructor': 'Larkin T',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'Argument and Advocacy'},
#  {'CRN': '75543',
#   'CatalogID': 'CO0101',
#   'Credits': '3',
#   'Instructor': 'Smith J',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Argument and Advocacy'},
#  {'CRN': '75544',
#   'CatalogID': 'CO0101',
#   'Credits': '3',
#   'Instructor': 'Smith J',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Argument and Advocacy'},
#  {'CRN': '76782',
#   'CatalogID': 'CO0102',
#   'Credits': '3',
#   'Instructor': 'Arendt C',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MW 0500-0615pm'],
#   'Title': 'Intro to Public Relations'},
#  {'CRN': '75334',
#   'CatalogID': 'CO0130',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Mass Media and Society'},
#  {'CRN': '75335',
#   'CatalogID': 'CO0130',
#   'Credits': '3',
#   'Instructor': 'Duarte L',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['R 0700-0930pm'],
#   'Title': 'Mass Media and Society'},
#  {'CRN': '76495',
#   'CatalogID': 'CO0130',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['TF 0800-0915am'],
#   'Title': 'Mass Media and Society'},
#  {'CRN': '75234',
#   'CatalogID': 'CO0200',
#   'Credits': '3',
#   'Instructor': 'Nuru A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Interpersonal Comm Theories'},
#  {'CRN': '75472',
#   'CatalogID': 'CO0200',
#   'Credits': '3',
#   'Instructor': 'Ryan M',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Interpersonal Comm Theories'},
#  {'CRN': '75195',
#   'CatalogID': 'CO0220',
#   'Credits': '3',
#   'Instructor': 'Pagano M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Intro Organizational Comm'},
#  {'CRN': '76249',
#   'CatalogID': 'CO0231',
#   'Credits': '3',
#   'Instructor': 'Gil-Egui G',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Media Institutions'},
#  {'CRN': '76759',
#   'CatalogID': 'CO0231',
#   'Credits': '3',
#   'Instructor': 'Gil-Egui G',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Media Institutions'},
#  {'CRN': '76760',
#   'CatalogID': 'CO0236',
#   'Credits': '3',
#   'Instructor': 'Gudelunas D',
#   'Section': 'A',
#   'Tags': ['USDiv'],
#   'Timecodes': ['M 0500-0730pm'],
#   'Title': 'Gender, Sexuality, and Media'},
#  {'CRN': '76250',
#   'CatalogID': 'CO0238',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Comm & Popular Culture'},
#  {'CRN': '75545',
#   'CatalogID': 'CO0248',
#   'Credits': '3',
#   'Instructor': 'Pagano M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Health Communication'},
#  {'CRN': '75137',
#   'CatalogID': 'CO0309',
#   'Credits': '3',
#   'Instructor': 'Wills M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Research Proj in Comm:Capstone'},
#  {'CRN': '75138',
#   'CatalogID': 'CO0309',
#   'Credits': '3',
#   'Instructor': 'Wills M',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Research Proj in Comm:Capstone'},
#  {'CRN': '75174',
#   'CatalogID': 'CO0309',
#   'Credits': '3',
#   'Instructor': 'Nuru A',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Research Proj in Comm:Capstone'},
#  {'CRN': '75720',
#   'CatalogID': 'CO0309',
#   'Credits': '3',
#   'Instructor': 'Nuru A',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Research Proj in Comm:Capstone'},
#  {'CRN': '76761',
#   'CatalogID': 'CO0321',
#   'Credits': '3',
#   'Instructor': 'Pagano M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0500-0615pm'],
#   'Title': 'Comm Proc in Orgs: Negotiation'},
#  {'CRN': '76762',
#   'CatalogID': 'CO0331',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'American Media / Amer History'},
#  {'CRN': '76763',
#   'CatalogID': 'CO0342',
#   'Credits': '3',
#   'Instructor': 'Gil-Egui G',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0500-0730pm'],
#   'Title': 'Technoculture & Info Society'},
#  {'CRN': '76254',
#   'CatalogID': 'CO0345',
#   'Credits': '3',
#   'Instructor': 'Zhang Q',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Relational Communication'},
#  {'CRN': '76764',
#   'CatalogID': 'CO0346',
#   'Credits': '3',
#   'Instructor': 'Wills M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Communication and Spirituality'},
#  {'CRN': '75142',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Aksan A',
#   'Section': 'C01',
#   'Tags': ['CRNST'],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75143',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Lane P',
#   'Section': 'C02',
#   'Tags': ['CRNST'],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75388',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Aksan A',
#   'Section': 'C03',
#   'Tags': ['CRNST'],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75877',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Murray T',
#   'Section': 'C04',
#   'Tags': ['CRNST'],
#   'Timecodes': ['TF 0800-0915am'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75878',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Murray T',
#   'Section': 'C05',
#   'Tags': ['CRNST'],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '76116',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Murray T',
#   'Section': 'C06',
#   'Tags': ['CRNST'],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75141',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Franceschi D',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75144',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Franceschi D',
#   'Section': 'H',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75145',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'McCloghry G',
#   'Section': 'I',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75146',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Martin T',
#   'Section': 'J',
#   'Tags': [],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75147',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Martin T',
#   'Section': 'K',
#   'Tags': [],
#   'Timecodes': ['TF 0330-0445pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75386',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Martin T',
#   'Section': 'L',
#   'Tags': [],
#   'Timecodes': ['MR 0500-0615pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75387',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'McCloghry G',
#   'Section': 'M',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75389',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Shadmani H',
#   'Section': 'N',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75732',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Martin T',
#   'Section': 'O',
#   'Tags': [],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75869',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Shadmani H',
#   'Section': 'P',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '76492',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Shadmani H',
#   'Section': 'Q',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '76506',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'R',
#   'Tags': [],
#   'Timecodes': ['TBA'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '76507',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'S',
#   'Tags': [],
#   'Timecodes': ['TBA'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '76508',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'T',
#   'Tags': [],
#   'Timecodes': ['TBA'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '76509',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'U',
#   'Tags': [],
#   'Timecodes': ['TBA'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '76928',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'V',
#   'Tags': [],
#   'Timecodes': ['TBA'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '76929',
#   'CatalogID': 'EC0114',
#   'Credits': '3',
#   'Instructor': 'Nantz K',
#   'Section': 'A',
#   'Tags': ['USDiv'],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Race,Class,Gendr in Amer Wkplc'},
#  {'CRN': '75006',
#   'CatalogID': 'EC0204',
#   'Credits': '3',
#   'Instructor': 'Nantz K',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Interm Microeconomic Theory'},
#  {'CRN': '75193',
#   'CatalogID': 'EC0204',
#   'Credits': '3',
#   'Instructor': 'Nantz K',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Interm Microeconomic Theory'},
#  {'CRN': '75493',
#   'CatalogID': 'EC0204L',
#   'Credits': '1',
#   'Instructor': 'Nantz K',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0100-0150pm'],
#   'Title': 'Interm Micro Econ Theory Lab'},
#  {'CRN': '75007',
#   'CatalogID': 'EC0210',
#   'Credits': '3',
#   'Instructor': 'Lane P',
#   'Section': 'A',
#   'Tags': ['ResColl'],
#   'Timecodes': ['MR 0930-1020am', 'W 0900-0950am'],
#   'Title': 'Money and Banking'},
#  {'CRN': '76363',
#   'CatalogID': 'EC0230',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': ['WDiv'],
#   'Timecodes': ['TF 0330-0445pm'],
#   'Title': 'Comparative Economic Systems'},
#  {'CRN': '76930',
#   'CatalogID': 'EC0235',
#   'Credits': '3',
#   'Instructor': 'Aksan A',
#   'Section': 'A',
#   'Tags': ['WDiv'],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Economic Development'},
#  {'CRN': '75008',
#   'CatalogID': 'EC0278',
#   'Credits': '3',
#   'Instructor': 'Vasquez Mazariegos',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Statistics'},
#  {'CRN': '76931',
#   'CatalogID': 'EC0278',
#   'Credits': '3',
#   'Instructor': 'Vasquez Mazariegos',
#   'Section': 'B',
#   'Tags': [],
# ...
#   'Section': 'B',
#   'Tags': ['Water'],
#   'Timecodes': ['TF 0330-0445pm'],
#   'Title': 'Public Relations'},
#  {'CRN': '75265',
#   'CatalogID': 'OM0101',
#   'Credits': '3',
#   'Instructor': 'He J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Operations Management'},
#  {'CRN': '75266',
#   'CatalogID': 'OM0101',
#   'Credits': '3',
#   'Instructor': 'He J',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Operations Management'},
#  {'CRN': '75267',
#   'CatalogID': 'OM0101',
#   'Credits': '3',
#   'Instructor': 'Lee P',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Operations Management'},
#  {'CRN': '75268',
#   'CatalogID': 'OM0101',
#   'Credits': '3',
#   'Instructor': 'Lee P',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Operations Management'},
#  {'CRN': '75269',
#   'CatalogID': 'OM0101',
#   'Credits': '3',
#   'Instructor': 'Lee P',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'Operations Management'},
#  {'CRN': '76387',
#   'CatalogID': 'OM0101',
#   'Credits': '3',
#   'Instructor': 'Krishnamoorthy J',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['T 0630-0900pm'],
#   'Title': 'Operations Management'},
#  {'CRN': '76699',
#   'CatalogID': 'OM0101',
#   'Credits': '3',
#   'Instructor': 'Sklar D',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['R 0600-0900pm'],
#   'Title': 'Operations Management'},
#  {'CRN': '75278',
#   'CatalogID': 'EG0031',
#   'Credits': '3',
#   'Instructor': 'Munden R',
#   'Section': 'C01',
#   'Tags': ['CRNST'],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Fundamentals of Engineering I'},
#  {'CRN': '75848',
#   'CatalogID': 'EG0031',
#   'Credits': '3',
#   'Instructor': 'Munden R',
#   'Section': 'C02',
#   'Tags': ['CRNST'],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Fundamentals of Engineering I'},
#  {'CRN': '76726',
#   'CatalogID': 'EG0031',
#   'Credits': '3',
#   'Instructor': 'Munden R',
#   'Section': 'C03',
#   'Tags': ['CRNST'],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Fundamentals of Engineering I'},
#  {'CRN': '75488',
#   'CatalogID': 'EG0390',
#   'Credits': '3',
#   'Instructor': 'Munden R',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0500-0615pm'],
#   'Title': 'Senior Design Project I'},
#  {'CRN': '75574',
#   'CatalogID': 'CD0212',
#   'Credits': '3',
#   'Instructor': 'Waugh K',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0630-0900pm'],
#   'Title': 'Engineering Graphics II (CATIA)'},
#  {'CRN': '76400',
#   'CatalogID': 'CR0246',
#   'Credits': '3',
#   'Instructor': 'Cavallo J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Digital Electronics Design II'},
#  {'CRN': '76710',
#   'CatalogID': 'CR0325',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'Computer Graphics'},
#  {'CRN': '76711',
#   'CatalogID': 'CR0331',
#   'Credits': '3',
#   'Instructor': 'Lyon D',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Biomedical Signal Processing'},
#  {'CRN': '76712',
#   'CatalogID': 'CR0346',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Computer System Architecture'},
#  {'CRN': '76728',
#   'CatalogID': 'EE0207',
#   'Credits': '3',
#   'Instructor': 'Govil P',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0630-0900pm'],
#   'Title': 'Electronic Materials'},
#  {'CRN': '75161',
#   'CatalogID': 'EE0213',
#   'Credits': '3',
#   'Instructor': 'Balaji U',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Intro to Electric Circuits'},
#  {'CRN': '75226',
#   'CatalogID': 'EE0213',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'Intro Electric Circuits(PS/EG)'},
#  {'CRN': '75710',
#   'CatalogID': 'EE0213L',
#   'Credits': '1',
#   'Instructor': 'Cavallo J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0630-0830pm'],
#   'Title': 'Electric Circuits Lab (PS/EG)'},
#  {'CRN': '75711',
#   'CatalogID': 'EE0213L',
#   'Credits': '1',
#   'Instructor': 'Denenberg J',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Electric Circuits Lab'},
#  {'CRN': '76125',
#   'CatalogID': 'EE0213L',
#   'Credits': '1',
#   'Instructor': 'Denenberg J',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['T 0200-0430pm'],
#   'Title': 'Electric Circuits Lab'},
#  {'CRN': '75204',
#   'CatalogID': 'EE0231',
#   'Credits': '3',
#   'Instructor': 'Balaji U',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Intro to ElectCircuits&Devices'},
#  {'CRN': '75717',
#   'CatalogID': 'EE0231L',
#   'Credits': '1',
#   'Instructor': 'Denenberg J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0500-0730pm'],
#   'Title': 'Electronics Circuits Lab'},
#  {'CRN': '75205',
#   'CatalogID': 'EE0301',
#   'Credits': '3',
#   'Instructor': 'Balaji U',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Signal & Systems I'},
#  {'CRN': '76723',
#   'CatalogID': 'EE0315',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['F 0630-0900pm'],
#   'Title': 'Nanoelectronics'},
#  {'CRN': '75409',
#   'CatalogID': 'EE0346',
#   'Credits': '3',
#   'Instructor': 'Lopes E',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0630-0900pm'],
#   'Title': 'Embedded Microcontrollers'},
#  {'CRN': '76724',
#   'CatalogID': 'EE0383',
#   'Credits': '3',
#   'Instructor': 'Denenberg J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0630-0900pm'],
#   'Title': 'Wireless Systems I'},
#  {'CRN': '76725',
#   'CatalogID': 'EE0385',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['U 0930-1130am'],
#   'Title': 'Powr Generation & Distribution'},
#  {'CRN': '75208',
#   'CatalogID': 'MC0290',
#   'Credits': '3',
#   'Instructor': 'Srinivas Sundarram S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Engineering Systems Dynamics'},
#  {'CRN': '76401',
#   'CatalogID': 'MC0290',
#   'Credits': '3',
#   'Instructor': 'Srinivas Sundarram S',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Engineering Systems Dynamics'},
#  {'CRN': '75300',
#   'CatalogID': 'ME0201',
#   'Credits': '3',
#   'Instructor': 'Zabinski M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Engineering Statics'},
#  {'CRN': '75815',
#   'CatalogID': 'ME0201',
#   'Credits': '3',
#   'Instructor': 'Zabinski M',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'Engineering Statics'},
#  {'CRN': '76729',
#   'CatalogID': 'ME0201',
#   'Credits': '3',
#   'Instructor': 'Zabinski M',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['MR 0500-0615pm'],
#   'Title': 'Engineering Statics'},
#  {'CRN': '75713',
#   'CatalogID': 'ME0206L',
#   'Credits': '1',
#   'Instructor': 'Selsky G',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 1230-0230pm'],
#   'Title': 'Mechanics Lab'},
#  {'CRN': '75714',
#   'CatalogID': 'ME0206L',
#   'Credits': '1',
#   'Instructor': 'Selsky G',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['T 0330-0530pm'],
#   'Title': 'Mechanics Lab'},
#  {'CRN': '75744',
#   'CatalogID': 'ME0206L',
#   'Credits': '1',
#   'Instructor': 'Selsky G',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['T 0630-0830pm'],
#   'Title': 'Mechanics Lab'},
#  {'CRN': '75247',
#   'CatalogID': 'ME0241',
#   'Credits': '3',
#   'Instructor': 'Etemad S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'Principles of Thermodynamics'},
#  {'CRN': '75064',
#   'CatalogID': 'ME0241',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'Principles of Thermodynamics'},
#  {'CRN': '75065',
#   'CatalogID': 'ME0311',
#   'Credits': '3',
#   'Instructor': 'Srinivas Sundarram S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Machine Design'},
#  {'CRN': '76402',
#   'CatalogID': 'ME0311',
#   'Credits': '3',
#   'Instructor': 'Dornfeld W',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['R 0630-0900pm'],
#   'Title': 'Machine Design'},
#  {'CRN': '76730',
#   'CatalogID': 'ME0319',
#   'Credits': '3',
#   'Instructor': 'Bauer G',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0630-0900pm'],
#   'Title': 'Appl of Finite Element Analys'},
#  {'CRN': '76399',
#   'CatalogID': 'ME0321',
#   'Credits': '3',
#   'Instructor': 'Gunawardana R',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'Advanced Kinematics'},
#  {'CRN': '75465',
#   'CatalogID': 'ME0322',
#   'Credits': '3',
#   'Instructor': 'Judge A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0630-0900pm'],
#   'Title': 'Advanced Dynamics'},
#  {'CRN': '76731',
#   'CatalogID': 'ME0346',
#   'Credits': '3',
#   'Instructor': 'Anekwe C',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0630-0900pm'],
#   'Title': 'Energy Conversion'},
#  {'CRN': '75573',
#   'CatalogID': 'ME0349',
#   'Credits': '3',
#   'Instructor': 'Etemad S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Heat Transfer'},
#  {'CRN': '75176',
#   'CatalogID': 'ME0349',
#   'Credits': '3',
#   'Instructor': 'Etemad S',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Heat Transfer'},
#  {'CRN': '75715',
#   'CatalogID': 'ME0350L',
#   'Credits': '1',
#   'Instructor': 'Wojna R',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0330-0530pm'],
#   'Title': 'Energy Transfer Lab'},
#  {'CRN': '75716',
#   'CatalogID': 'ME0350L',
#   'Credits': '1',
#   'Instructor': 'Cupic K',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['M 0630-0830pm'],
#   'Title': 'Energy Transfer Lab'},
#  {'CRN': '75466',
#   'CatalogID': 'MF0207',
#   'Credits': '3',
#   'Instructor': 'Lutian M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Materials Science'},
#  {'CRN': '75742',
#   'CatalogID': 'MF0207',
#   'Credits': '3',
#   'Instructor': 'Lutian M',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['R 0630-0900pm'],
#   'Title': 'Materials Science'},
#  {'CRN': '76404',
#   'CatalogID': 'MF0350',
#   'Credits': '3',
#   'Instructor': 'Craciun C',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0630-0900pm'],
#   'Title': 'Adv Prog LogicContrl (PLC)Syst'},
#  {'CRN': '75206',
#   'CatalogID': 'SW0201',
#   'Credits': '3',
#   'Instructor': 'Rusu A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0200-0430pm'],
#   'Title': 'Software Engineering Methods'},
#  {'CRN': '75306',
#   'CatalogID': 'SW0202',
#   'Credits': '3',
#   'Instructor': 'Rusu A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'Software Design Methods'},
#  {'CRN': '75816',
#   'CatalogID': 'SW0204',
#   'Credits': '3',
#   'Instructor': 'Guelakis W',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0630-0900pm'],
#   'Title': 'Software Project Management'},
#  {'CRN': '75817',
#   'CatalogID': 'SW0232',
#   'Credits': '3',
#   'Instructor': 'LaMastra P',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0630-0900pm'],
#   'Title': 'Adv Programm & Data Structures'},
#  {'CRN': '75307',
#   'CatalogID': 'SW0304',
#   'Credits': '3',
#   'Instructor': 'Rusu A',
#   'Section': 'A',
#   'Tags': ['SerL'],
#   'Timecodes': ['T 1100-0130pm'],
#   'Title': 'Web Development'},
#  {'CRN': '75207',
#   'CatalogID': 'SW0355',
#   'Credits': '3',
#   'Instructor': 'Corcoran J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0630-0900pm'],
#   'Title': 'Database Management Systems'},
#  {'CRN': '76734',
#   'CatalogID': 'SW0380',
#   'Credits': '3',
#   'Instructor': 'Guelakis W',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0200-0430pm'],
#   'Title': 'Health Information Systems'},
#  {'CRN': '75818',
#   'CatalogID': 'SW0382C',
#   'Credits': '3',
#   'Instructor': 'Govindaraja B',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'SpTopics: Android Applications'},
#  {'CRN': '75213',
#   'CatalogID': 'NS0110',
#   'Credits': '3',
#   'Instructor': 'OÕShea E',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Intro Professional Nursing'},
#  {'CRN': '75214',
#   'CatalogID': 'NS0112',
#   'Credits': '3',
#   'Instructor': 'Planas J',
#   'Section': 'A',
#   'Tags': ['USDiv', 'SerL'],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'HealthcareDeliverySystems'},
#  {'CRN': '76536',
#   'CatalogID': 'NS0112',
#   'Credits': '3',
#   'Instructor': 'Murphy M',
#   'Section': 'B',
#   'Tags': ['USDiv', 'SerL'],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Healthcare Delivery Systems'},
#  {'CRN': '75252',
#   'CatalogID': 'NS0250',
#   'Credits': '3',
#   'Instructor': 'Pomarico C',
#   'Section': 'A',
#   'Tags': ['USDiv', 'RNNU'],
#   'Timecodes': ['T 0530-0800pm'],
#   'Title': 'Professional Nursing for RNÕs'},
#  {'CRN': '75577',
#   'CatalogID': 'NS0272',
#   'Credits': '4',
#   'Instructor': 'Kris A',
#   'Section': 'A',
#   'Tags': ['ResColl'],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Geriatric Nursing'},
#  {'CRN': '75606',
#   'CatalogID': 'NS0272C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0700-0200pm'],
#   'Title': 'Geriatric Nursing Clinical'},
#  {'CRN': '75609',
#   'CatalogID': 'NS0272C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['F 0700-0200pm'],
#   'Title': 'Geriatric Nursing Clinical'},
#  {'CRN': '75615',
#   'CatalogID': 'NS0272C',
#   'Credits': '0',
#   'Instructor': 'Saracino K',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['F 0700-0200pm'],
#   'Title': 'Geriatric Nursing Clinical'},
#  {'CRN': '75616',
#   'CatalogID': 'NS0272C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['W 0700-0200pm'],
#   'Title': 'Geriatric Nursing Clinical'},
#  {'CRN': '76738',
#   'CatalogID': 'NS0272C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['T 0700-0200pm'],
#   'Title': 'Geriatric Nursing Clinical'},
#  {'CRN': '75215',
#   'CatalogID': 'NS0301',
#   'Credits': '4',
#   'Instructor': 'Planas J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Health and Wellness'},
#  {'CRN': '76739',
#   'CatalogID': 'NS0301',
#   'Credits': '4',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'Health and Wellness'},
#  {'CRN': '75823',
#   'CatalogID': 'NS0301',
#   'Credits': '4',
#   'Instructor': 'Lovanio K',
#   'Section': 'S',
#   'Tags': ['SDNU'],
#   'Timecodes': ['TF 0200-0500pm'],
#   'Title': 'Health and Wellness'},
#  {'CRN': '75648',
#   'CatalogID': 'NS0301C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0800-0300pm'],
#   'Title': 'Health and Wellness Clinical'},
#  {'CRN': '75649',
#   'CatalogID': 'NS0301C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['F 0800-0300pm'],
#   'Title': 'Health and Wellness Clinical'},
#  {'CRN': '75651',
#   'CatalogID': 'NS0301C',
#   'Credits': '0',
#   'Instructor': 'Saracino K',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['W 0800-0300pm'],
#   'Title': 'Health and Wellness Clinical'},
#  {'CRN': '75652',
#   'CatalogID': 'NS0301C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['F 0800-0300pm'],
#   'Title': 'Health and Wellness Clinical'},
#  {'CRN': '75654',
#   'CatalogID': 'NS0301C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['W 0800-0300pm'],
#   'Title': 'Health and Wellness Clinical'},
#  {'CRN': '75656',
#   'CatalogID': 'NS0301C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['F 0800-0300pm'],
#   'Title': 'Health and Wellness Clinical'},
#  {'CRN': '75658',
#   'CatalogID': 'NS0301C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['T 0800-0300pm'],
#   'Title': 'Health and Wellness Clinical'},
#  {'CRN': '75659',
#   'CatalogID': 'NS0301C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'H',
#   'Tags': [],
#   'Timecodes': ['W 0800-0300pm'],
#   'Title': 'Health and Wellness Clinical'},
#  ...]

# %% [markdown]
# To get an idea of how the data looks like as a single denormalized table, we'll use Pandas's built-in JSON formatting library.

# %%
# DO NOT EDIT THIS CELL
from pandas.io.json import json_normalize
json_normalize(course_specs).set_index('CRN')
# Out:
#       CatalogID Credits       Instructor Section  \
# CRN
# 76407    AS0200       3         Bayers P       A
# 76513    AS0400       3         Garvey J      01
# 76934    AS0488       3         Bayers P      01
# 76935  ASEN0490       3          Lopez E      01
# 75478    AY0010       3           Lacy S     C01
# 75479    AY0010       3           Lacy S     C02
# 75752    AY0052       3       Crawford D       A
# 76300    AY0052       3         Wilson J       B
# 75297    AY0110       3         Wilson J       A
# 75728    AY0111       3       Crawford D       A
# 76753    AY0111       3        Wessler S       B
# 76758    AY0115       3        Aronsen G       A
# 76303    AY0152       3       Crawford D       A
# 76754    AY0168       3        Wessler S       A
# 75333    AE0262       3         Liftig R       A
# 75233    AE0265       3         Liftig R       A
# 75282    AE0276       3            Day R       A
# 76234    AE0281       3         Butler B       A
# 76826    AE0284       3          Brown D       A
# 75125    AE0284       3          Brown D       B
# 75001    AE0285       3            STAFF       A
# 75002    AE0291       3        Schmidt D       A
# 75003    AE0291       3  Sticca-Conrod L       B
# 75070    AE0291       3  Sticca-Conrod L       C
# 75308    AE0291       3      Ventrella S       D
# 75313    AE0291       3          Yoder J       E
# 76827    AE0291       3        Schmidt N       F
# 76828    AE0291       3        Schmidt D       G
# 75344    AR0110       3          Douda A       A
# 75402    AR0210       3          Douda A       A
# ...         ...     ...              ...     ...
# 75839   NS0312C       0            STAFF       E
# 76062   NS0312C       0            STAFF       F
# 75384    NS0314       4      LoGiudice J       A
# 75630   NS0314C       0       Manister N       A
# 75631   NS0314C       0       Manister N       B
# 75632   NS0314C       0        Burrows K       C
# 75709   NS0314C       0            STAFF       D
# 76751   NS0314C       0      LoGiudice J       E
# 75237    NS0323       4         OÕShea E       A
# 75633   NS0323C       0          Roney L       A
# 75634   NS0323C       0            STAFF       B
# 75635   NS0323C       0            STAFF       C
# 75636   NS0323C       0            STAFF       D
# 75637   NS0323C       0            STAFF       E
# 75832   NS0323C       0            STAFF       F
# 75833   NS0323C       0          Roney L       G
# 75238    NS0325       5        Chaplik S       A
# 75239    NS0325       5         Sumpio C       B
# 75638   NS0325C       0   Iannino-Renz R       A
# 75639   NS0325C       0   Iannino-Renz R       B
# 75640   NS0325C       0            STAFF       C
# 75641   NS0325C       0         Bartos S       D
# 75642   NS0325C       0            STAFF       E
# 75643   NS0325C       0            STAFF       F
# 75644   NS0325C       0            STAFF       G
# 75645   NS0325C       0            STAFF       H
# 75396    NS0330       4          Mager D       A
# 75676   NS0330C       0            STAFF       A
# 75678   NS0330C       0            STAFF       B
# 76752   NS0330C       0            STAFF       C
#
#                                 Tags         Timecodes  \
# CRN
# 76407                             []  [MR 0930-1045am]
# 76513                [By Permission]   [W 0630-0830pm]
# 76934                [By Permission]   [M 0630-0830pm]
# 76935                [By Permission]   [T 0545-0745pm]
# 75478                  [CRNST, WDiv]  [TF 1230-0145pm]
# 75479                  [CRNST, WDiv]  [TF 1100-1215pm]
# 75752                             []  [TR 0630-0745pm]
# 76300                             []  [MR 0930-1045am]
# 75297                             []   [M 0630-0900pm]
# 75728                         [WDiv]  [MR 1230-0145pm]
# 76753                         [WDiv]  [TF 0200-0315pm]
# 76758                             []   [T 0630-0900pm]
# 76303                [WDiv, ResColl]  [MR 0930-1045am]
# 76754                         [WDiv]  [TF 0330-0445pm]
# 75333                        [USDiv]   [W 0200-0430pm]
# 75233                        [USDiv]  [TR 0500-0615pm]
# 75282                         [WDiv]  [MR 0930-1045am]
# 76234                             []   [T 0630-0900pm]
# 76826                             []  [WF 0800-0915am]
# 75125                             []   [R 0630-0900pm]
# 75001                             []  [MW 0500-0615pm]
# 75002                             []  [MR 0800-0915am]
# 75003                             []          [Online]
# 75070                             []          [Online]
# 75308                             []   [T 0630-0900pm]
# 75313                             []   [W 0630-0900pm]
# 76827                             []   [W 1100-0130pm]
# 76828                             []   [M 0630-0900pm]
# 75344                             []  [MW 0300-0445pm]
# 75402                             []  [MW 0500-0645pm]
# ...                              ...               ...
# 75839                         [SDNU]   [W 1230-0730pm]
# 76062                         [SDNU]   [R 0100-0800pm]
# 75384                             []  [MR 0930-1045am]
# 75630                             []   [T 0700-0100pm]
# 75631                             []   [W 0700-0100pm]
# 75632                             []   [W 0700-0100pm]
# 75709                             []   [F 0700-0100pm]
# 76751                             []   [T 0700-0100pm]
# 75237                         [SerL]  [MR 0200-0315pm]
# 75633                             []   [T 0700-0100pm]
# 75634                             []   [T 0700-0100pm]
# 75635                             []   [W 0700-0100pm]
# 75636                             []   [W 0700-0100pm]
# 75637                             []   [T 0700-0100pm]
# 75832                             []   [T 0700-0100pm]
# 75833                             []   [T 0700-0100pm]
# 75238                             []  [MR 0330-0445pm]
# 75239                             []  [MR 1230-0145pm]
# 75638                             []   [T 0100-0800pm]
# 75639                             []   [W 0700-0200pm]
# 75640                             []   [W 0700-0200pm]
# 75641                             []   [W 0700-0200pm]
# 75642                             []   [F 0700-0200pm]
# 75643                             []   [F 0700-0200pm]
# 75644                             []   [T 0700-0200pm]
# 75645                             []   [T 0700-0200pm]
# 75396                   [WDiv, RNNU]   [W 0530-0800pm]
# 75676                   [SerL, RNNU]   [W 0800-0430pm]
# 75678  [SerL, RNNU, Nicaragua, Jan.]   [W 0800-0430pm]
# 76752                   [SerL, RNNU]   [W 0800-0430pm]
#
#                                 Title
# CRN
# 76407       Roots of American Culture
# 76513    Critical Issues/Amer Studies
# 76934    Frontier in American Culture
# 76935    Contemporary American Memoir
# 75478    Intro to Four-Field Anthropo
# 75479    Intro to Four-Field Anthropo
# 75752   Culture and Political Economy
# 76300   Culture and Political Economy
# 75297         Biological Anthropology
# 75728           Cultural Anthropology
# 76753           Cultural Anthropology
# 76758         Biomedical Anthropology
# 76303    Islamic Societies & Cultures
# 76754   Women & Men: Anthro of Gender
# 75333        Ethics and the Community
# 75233             Ethics in Education
# 75282  Ethical DimensGlobal BusPolicy
# 76234        Ethics of Communications
# 76826            Environmental Ethics
# 75125            Environmental Ethics
# 75001           Ethics of Health Care
# 75002                 Business Ethics
# 75003                 Business Ethics
# 75070                 Business Ethics
# 75308                 Business Ethics
# 75313                 Business Ethics
# 76827                 Business Ethics
# 76828                 Business Ethics
# 75344             Elementary Arabic I
# 75402           Intermediate Arabic I
# ...                               ...
# 75839  Medl Surgical Nursing I Clinic
# 76062  Medl Surgical Nursing I Clinic
# 75384    Maternal and Newborn Nursing
# 75630   Maternal/Newborn Nursing Clin
# 75631   Maternal/Newborn Nursing Clin
# 75632   Maternal/Newborn Nursing Clin
# 75709   Maternal/Newborn Nursing Clin
# 76751   Maternal/Newborn Nursing Clin
# 75237               Pediatric Nursing
# 75633      Pediatric Nursing Clinical
# 75634      Pediatric Nursing Clinical
# 75635      Pediatric Nursing Clinical
# 75636      Pediatric Nursing Clinical
# 75637      Pediatric Nursing Clinical
# 75832      Pediatric Nursing Clinical
# 75833      Pediatric Nursing Clinical
# 75238     Medical Surgical Nursing II
# 75239     Medical Surgical Nursing II
# 75638  Med Surgical Nursing II Clinic
# 75639  Med Surgical Nursing II Clinic
# 75640  Med Surgical Nursing II Clinic
# 75641  Med Surgical Nursing II Clinic
# 75642  Med Surgical Nursing II Clinic
# 75643  Med Surgical Nursing II Clinic
# 75644  Med Surgical Nursing II Clinic
# 75645  Med Surgical Nursing II Clinic
# 75396   Comm,Pub & Globl Hlth Nursing
# 75676     CommPub&GlblHlthNsCllinical
# 75678     CommPub&GlblHlthNsCllinical
# 76752     CommPub&GlblHlthNsCllinical
#
# [1070 rows x 7 columns]

# %% [markdown]
# Based on your interpretation of the data, **write out the table schema** in **TABLENAME(<u>PK</u>, Attributes, *FK*)** notation. Each PK should be underlined. Each FK should be italics, and the other columns should be plain text. Please list one table per line.
#
# Hints:
# * To see how to underline and italicize in Markdown, just double-click this cell. <!-- You can mix HTML in with Markdown, so underlining is just a <u>...</u> element. -->
# * To force text to appear on a new line you can either use two spaces at the end of the line above<!-- or use an HTML `<br>` tag -->.
# * You can answer this question with just four tables.
# * Two sections with the same CatalogID can have different titles (e.g., for EN11), so treat the titles as section-specific.
# * Credits are specified in the course catalog. They are sometimes are given as a range (e.g., 1-3) instead of as integers, so you may want to use a string.
# * Items in the table above that look like lists **are** lists and need to handled as such.
# * There is a reason why `CRN` was chosen as the index to the DataFrame.
# * Since the only data you have for each faculty member is a name, just treat the instructor names as value objects.
# * You may add surrogate keys if you like, but it's not strictly necessary if you use composite keys.

# %% [markdown]
# ### Table Schema
# **COURSE_OFFERING(<u>CourseOfferingID</u>, CRN, Credits, Instructor, *CourseID*, *TimeID*)** <br>
# **COURSE(<u>CourseID</u>, CatalogID, Sections, Title)** <br>
# **COURSETIME(<u>TimeID</u>, TimeCodes)** <br>
# **COURSETAG(<u>TagID</u>, Tags, *CourseOfferingID*)**

# %% [markdown]
# ## 5. (8 points) Write DDL to create your tables (with keys) in the database.
# Suggestions:
# * Use `%%sql` so you can do this on one cell.
# * Use DROP TABLE IF EXISTS for each table before creating it. You've seen this done in a couple of demos so far.

# %%
# %%sql
#
# /* *** Create COURSE table into database  *** */
# CREATE TABLE IF NOT EXISTS COURSE (
#     CourseID INTEGER PRIMARY KEY,
#     CatalogID TEST NOT NULL,
#     Section TEXT NOT NULL,
#     Title TEXT NOT NULL
# );
#
# /* *** Create COURSETIME table into database  *** */
# CREATE TABLE IF NOT EXISTS COURSETIME (
#     TimeID INTEGER PRIMARY KEY,
#     TimeCodes TEXT NOT NULL
# );
#
# /* *** Create COURSE_OFFERING table into database  *** */
# CREATE TABLE IF NOT EXISTS COURSE_OFFERING (
#     CourseOfferingID INTEGER PRIMARY KEY,
#     CRN TEXT NOT NULL,
#     Credits TEXT NOT NULL,
#     Instructor TEXT,
#     CourseID Integer,
#     TImeID Integer,
#     FOREIGN KEY (CourseID) REFERENCES COURSE (CourseID),
#     FOREIGN KEY (TimeID) REFERENCES COURSETIME (TimeID)
# );
#
# /* *** Create COURSETAG table into database  *** */
# CREATE TABLE IF NOT EXISTS COURSETAG (
#     TagID INTEGER PRIMARY KEY,
#     Tags TEXT,
#     CourseOfferingID Integer,
#     FOREIGN KEY (CourseOfferingID) REFERENCES COURSE_OFFERING (CourseOfferingID)
# );
# Out:
# Done.
# Done.
# Done.
# Done.
# []

# %%
# %%sql
# pragma table_info('COURSE');
# Out:
# Done.
# [(0, 'CourseID', 'INTEGER', 0, None, 1),
#  (1, 'CatalogID', 'TEST', 1, None, 0),
#  (2, 'Section', 'TEXT', 1, None, 0),
#  (3, 'Title', 'TEXT', 1, None, 0)]

# %%
# %%sql
# pragma table_info('COURSE_OFFERING');
# Out:
# Done.
# [(0, 'CourseOfferingID', 'INTEGER', 0, None, 1),
#  (1, 'CRN', 'TEXT', 1, None, 0),
#  (2, 'Credits', 'TEXT', 1, None, 0),
#  (3, 'Instructor', 'TEXT', 0, None, 0),
#  (4, 'CourseID', 'Integer', 0, None, 0),
#  (5, 'TImeID', 'Integer', 0, None, 0)]

# %%
# %%sql
# pragma table_info('COURSETAG');
# Out:
# Done.
# [(0, 'TagID', 'INTEGER', 0, None, 1),
#  (1, 'Tags', 'TEXT', 1, None, 0),
#  (2, 'CourseOfferingID', 'Integer', 0, None, 0)]

# %% [markdown]
# ## 4. (up to 8 points) Assemble the data into lists of dicts.
# Each table in your design is a list. Each record in the table is then a dictionary, with the column names as the keys.
#
# There are two approaches you can take:
# 1. (4 points) Construct the lists (and nested dictionaries) by hand. Each list needs to have at least 5 records and cannot violate referential integrity rules.
# 2. (8 points) Extract the data by [Traversing](https://en.wikipedia.org/wiki/Tree_traversal) the `course_specs` tree. Here's a bit of pseudocode for the basic logic:
#
# ```
# initialize an empty set for each table in your design
# for each dict or list at level 1 of the course_specs tree:
#     add records (one or more dicts) to relevant sets
#     note values that represent PKs
#     for each dict or list found at level 2:
#         add records (one or more dicts) to relevant sets
#         note values that represent PKs
#         for each dict or list found at level 3:
#             ...
# ```
# Traversal Notes:
# * With each level you still have access to data in the level above. That allows you to set FKs as needed.
# * The easiest way to add `a_dict` to `a_list` is with `a_list += [a_dict]`.
# * Before adding `a_dict` to `a_list` you should make sure it is not already in the list. You can do that with `if a_dict not in a_list: ...`
# * List for strong entities will *tend* to be populated in level 1, children in level 2, grandchildren in level 3, ...

# %%
course_specs_len = len(course_specs)-1

## Create new list named course_list based on COURSE(-CourseID-, CatalogID, Sections, Title)
course_list = []

for i in range(0, course_specs_len):
    d = {};
    
    cs = course_specs[i]
    
    catalog_id = cs['CatalogID']
    section = cs['Section']
    title = cs['Title']
    
    d['CatalogID'] = catalog_id
    d['Section'] = section
    d['Title'] = title

    if(d not in course_list):
        course_list.append(d);

# %%
course_specs_len = len(course_specs)-1

# Create new list named coursetime_list based on  COURSETIME(-TimeID-, TimeCodes) 
coursetime_list = []

for i in range(0, course_specs_len):
    d = {};
    
    cs = course_specs[i]
    
    timecodes = cs['Timecodes']

    d['Timecodes'] = timecodes

    if(d not in coursetime_list):
        coursetime_list.append(d);

# %%
course_specs_len = len(course_specs)-1

# Create new list named course_offering_list based on  COURSE_OFFERING(-CourseOfferingID-, CRN, Credits, Instructor, -CourseID-, -TimeID-) 
course_offering_list = []

for i in range(0, course_specs_len):
    d = {};
    
    cs = course_specs[i]
    
    crn = cs['CRN']
    credits = cs['Credits']
    instructor = cs['Instructor']

    d['CRN'] = crn
    d['Credits'] = credits
    d['Instructor'] = instructor

    if(d not in course_offering_list):
        course_offering_list.append(d);

course_offering_list
# Out:
# [{'CRN': '76407', 'Credits': '3', 'Instructor': 'Bayers P'},
#  {'CRN': '76513', 'Credits': '3', 'Instructor': 'Garvey J'},
#  {'CRN': '76934', 'Credits': '3', 'Instructor': 'Bayers P'},
#  {'CRN': '76935', 'Credits': '3', 'Instructor': 'Lopez E'},
#  {'CRN': '75478', 'Credits': '3', 'Instructor': 'Lacy S'},
#  {'CRN': '75479', 'Credits': '3', 'Instructor': 'Lacy S'},
#  {'CRN': '75752', 'Credits': '3', 'Instructor': 'Crawford D'},
#  {'CRN': '76300', 'Credits': '3', 'Instructor': 'Wilson J'},
#  {'CRN': '75297', 'Credits': '3', 'Instructor': 'Wilson J'},
#  {'CRN': '75728', 'Credits': '3', 'Instructor': 'Crawford D'},
#  {'CRN': '76753', 'Credits': '3', 'Instructor': 'Wessler S'},
#  {'CRN': '76758', 'Credits': '3', 'Instructor': 'Aronsen G'},
#  {'CRN': '76303', 'Credits': '3', 'Instructor': 'Crawford D'},
#  {'CRN': '76754', 'Credits': '3', 'Instructor': 'Wessler S'},
#  {'CRN': '75333', 'Credits': '3', 'Instructor': 'Liftig R'},
#  {'CRN': '75233', 'Credits': '3', 'Instructor': 'Liftig R'},
#  {'CRN': '75282', 'Credits': '3', 'Instructor': 'Day R'},
#  {'CRN': '76234', 'Credits': '3', 'Instructor': 'Butler B'},
#  {'CRN': '76826', 'Credits': '3', 'Instructor': 'Brown D'},
#  {'CRN': '75125', 'Credits': '3', 'Instructor': 'Brown D'},
#  {'CRN': '75001', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75002', 'Credits': '3', 'Instructor': 'Schmidt D'},
#  {'CRN': '75003', 'Credits': '3', 'Instructor': 'Sticca-Conrod L'},
#  {'CRN': '75070', 'Credits': '3', 'Instructor': 'Sticca-Conrod L'},
#  {'CRN': '75308', 'Credits': '3', 'Instructor': 'Ventrella S'},
#  {'CRN': '75313', 'Credits': '3', 'Instructor': 'Yoder J'},
#  {'CRN': '76827', 'Credits': '3', 'Instructor': 'Schmidt N'},
#  {'CRN': '76828', 'Credits': '3', 'Instructor': 'Schmidt D'},
#  {'CRN': '75344', 'Credits': '3', 'Instructor': 'Douda A'},
#  {'CRN': '75402', 'Credits': '3', 'Instructor': 'Douda A'},
#  {'CRN': '75745', 'Credits': '3', 'Instructor': 'Douda A'},
#  {'CRN': '76861', 'Credits': '3', 'Instructor': 'Poe A'},
#  {'CRN': '75165', 'Credits': '3', 'Instructor': 'Schwab K'},
#  {'CRN': '75166', 'Credits': '3', 'Instructor': 'Eliasoph P'},
#  {'CRN': '75559', 'Credits': '3', 'Instructor': 'Rose M'},
#  {'CRN': '75167', 'Credits': '3', 'Instructor': 'Eliasoph P'},
#  {'CRN': '75168', 'Credits': '3', 'Instructor': 'Eliasoph P'},
#  {'CRN': '75432', 'Credits': '3', 'Instructor': 'Rose M'},
#  {'CRN': '76860', 'Credits': '3', 'Instructor': 'Schwab K'},
#  {'CRN': '76317', 'Credits': '3', 'Instructor': 'Covaci I'},
#  {'CRN': '76318', 'Credits': '3', 'Instructor': 'Covaci I'},
#  {'CRN': '76862', 'Credits': '3', 'Instructor': 'Rose M'},
#  {'CRN': '76863', 'Credits': '3', 'Instructor': 'Eliasoph P'},
#  {'CRN': '76864', 'Credits': '3', 'Instructor': 'Cesiro L'},
#  {'CRN': '76865', 'Credits': '3', 'Instructor': 'Schwab K'},
#  {'CRN': '75456', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75944', 'Credits': '3', 'Instructor': 'Blough C'},
#  {'CRN': '76788', 'Credits': '3', 'Instructor': 'Blough C'},
#  {'CRN': '75219', 'Credits': '3', 'Instructor': 'Dutta I'},
#  {'CRN': '75304', 'Credits': '3', 'Instructor': 'Dutta I'},
#  {'CRN': '76460', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76461', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76287', 'Credits': '3', 'Instructor': 'Vernarelli J'},
#  {'CRN': '76789', 'Credits': '3', 'Instructor': 'Klug J'},
#  {'CRN': '76790', 'Credits': '3', 'Instructor': 'Choly J'},
#  {'CRN': '76235', 'Credits': '3', 'Instructor': 'Ortman B'},
#  {'CRN': '76236', 'Credits': '3', 'Instructor': 'Ortman B'},
#  {'CRN': '76791', 'Credits': '3', 'Instructor': 'Sauer G'},
#  {'CRN': '76422', 'Credits': '4', 'Instructor': 'Earls C'},
#  {'CRN': '75868', 'Credits': '4', 'Instructor': 'Earls C'},
#  {'CRN': '76423', 'Credits': '4', 'Instructor': 'DeCristofaro A'},
#  {'CRN': '76120', 'Credits': '4', 'Instructor': 'DeCristofaro A'},
#  {'CRN': '75617', 'Credits': '0', 'Instructor': 'Earls C'},
#  {'CRN': '75621', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75646', 'Credits': '0', 'Instructor': 'DeCristofaro A'},
#  {'CRN': '75647', 'Credits': '0', 'Instructor': 'DeCristofaro A'},
#  {'CRN': '75653', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '76060', 'Credits': '0', 'Instructor': 'Earls C'},
#  {'CRN': '76462', 'Credits': '0', 'Instructor': 'Earls C'},
#  {'CRN': '75279', 'Credits': '4', 'Instructor': 'Zavras E'},
#  {'CRN': '75662', 'Credits': '0', 'Instructor': 'Zavras E'},
#  {'CRN': '75663', 'Credits': '0', 'Instructor': 'Zavras E'},
#  {'CRN': '75664', 'Credits': '0', 'Instructor': 'Zavras E'},
#  {'CRN': '76424', 'Credits': '4', 'Instructor': 'Fernandez A'},
#  {'CRN': '75468', 'Credits': '4', 'Instructor': 'Fernandez A'},
#  {'CRN': '76425', 'Credits': '4', 'Instructor': 'Fernandez A'},
#  {'CRN': '75212', 'Credits': '4', 'Instructor': 'Fernandez A'},
#  {'CRN': '75665', 'Credits': '0', 'Instructor': 'Braun P'},
#  {'CRN': '75666', 'Credits': '0', 'Instructor': 'Biardi L'},
#  {'CRN': '75667', 'Credits': '0', 'Instructor': 'Andersen C'},
#  {'CRN': '75668', 'Credits': '0', 'Instructor': 'Phelan S'},
#  {'CRN': '75669', 'Credits': '0', 'Instructor': 'Andersen C'},
#  {'CRN': '75670', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75671', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75672', 'Credits': '0', 'Instructor': 'Braun P'},
#  {'CRN': '75673', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75674', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75675', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75677', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75679', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75680', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75681', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75682', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75683', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75684', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75685', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75686', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75687', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75250', 'Credits': '4', 'Instructor': 'Biardi J'},
#  {'CRN': '75688', 'Credits': '0', 'Instructor': 'Biardi J'},
#  {'CRN': '75689', 'Credits': '0', 'Instructor': 'Osier T'},
#  {'CRN': '75690', 'Credits': '0', 'Instructor': 'Osier T'},
#  {'CRN': '75691', 'Credits': '0', 'Instructor': 'Ansari J'},
#  {'CRN': '76430', 'Credits': '0', 'Instructor': 'Brousseau D'},
#  {'CRN': '75695', 'Credits': '1', 'Instructor': 'Gerry S'},
#  {'CRN': '75758', 'Credits': '1', 'Instructor': 'Gerry S'},
#  {'CRN': '75759', 'Credits': '1', 'Instructor': 'Gerry S'},
#  {'CRN': '76237', 'Credits': '1', 'Instructor': 'Gerry S'},
#  {'CRN': '76238', 'Credits': '1', 'Instructor': 'Gerry S'},
#  {'CRN': '76792', 'Credits': '1', 'Instructor': 'Gerry S'},
#  {'CRN': '76793', 'Credits': '4', 'Instructor': 'Gerry S'},
#  {'CRN': '76794', 'Credits': '0', 'Instructor': 'Gerry S'},
#  {'CRN': '75066', 'Credits': '3', 'Instructor': 'Harriott O'},
#  {'CRN': '76798', 'Credits': '4', 'Instructor': 'Vernarelli J'},
#  {'CRN': '76239', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76795', 'Credits': '1', 'Instructor': 'STAFF'},
#  {'CRN': '76796', 'Credits': '3', 'Instructor': 'Sauer G'},
#  {'CRN': '76797', 'Credits': '1', 'Instructor': 'Sauer G'},
#  {'CRN': '75415', 'Credits': '4', 'Instructor': 'Harriott O'},
#  {'CRN': '75694', 'Credits': '0', 'Instructor': 'Harriott O'},
#  {'CRN': '75575', 'Credits': '3', 'Instructor': 'Braun P'},
#  {'CRN': '75280', 'Credits': '4', 'Instructor': 'Brousseau D'},
#  {'CRN': '75692', 'Credits': '0', 'Instructor': 'Brousseau D'},
#  {'CRN': '75450', 'Credits': '4', 'Instructor': 'Byun S'},
#  {'CRN': '75693', 'Credits': '0', 'Instructor': 'Byun S'},
#  {'CRN': '76800', 'Credits': '3', 'Instructor': 'Phelan S'},
#  {'CRN': '76801', 'Credits': '3', 'Instructor': 'Andersen C'},
#  {'CRN': '75416', 'Credits': '3', 'Instructor': 'Biardi J'},
#  {'CRN': '75417', 'Credits': '2', 'Instructor': 'Biardi J'},
#  {'CRN': '76434', 'Credits': '3', 'Instructor': 'Biardi J'},
#  {'CRN': '75418', 'Credits': '3', 'Instructor': 'Biardi J'},
#  {'CRN': '76802', 'Credits': '3', 'Instructor': 'Biardi J'},
#  {'CRN': '76783', 'Credits': '3', 'Instructor': 'Harper-Leatherman A'},
#  {'CRN': '76100', 'Credits': '3', 'Instructor': 'OÕConnell E'},
#  {'CRN': '75152', 'Credits': '3', 'Instructor': 'Bethray S'},
#  {'CRN': '75293', 'Credits': '3', 'Instructor': 'Reilly-Wiedow E'},
#  {'CRN': '75589', 'Credits': '1', 'Instructor': 'STAFF'},
#  {'CRN': '75590', 'Credits': '1', 'Instructor': 'Reilly-Wiedow E'},
#  {'CRN': '75591', 'Credits': '1', 'Instructor': 'Reilly-Wiedow E'},
#  {'CRN': '76245', 'Credits': '1', 'Instructor': 'Reilly-Wiedow E'},
#  {'CRN': '75588', 'Credits': '3', 'Instructor': 'Steffen L'},
#  {'CRN': '75457', 'Credits': '3', 'Instructor': 'Sobczynski D'},
#  {'CRN': '75600', 'Credits': '3', 'Instructor': 'STAFF EG Only'},
#  {'CRN': '75601', 'Credits': '3', 'Instructor': 'Fischer R'},
#  {'CRN': '75602', 'Credits': '3', 'Instructor': 'Kubasik M'},
#  {'CRN': '75603', 'Credits': '3', 'Instructor': 'Weddle G'},
#  {'CRN': '75604', 'Credits': '3', 'Instructor': 'Weddle G'},
#  {'CRN': '75718', 'Credits': '3', 'Instructor': 'Fischer R'},
#  {'CRN': '75578', 'Credits': '1', 'Instructor': 'STAFF'},
#  {'CRN': '75579', 'Credits': '1', 'Instructor': 'STAFF'},
#  {'CRN': '75580', 'Credits': '1', 'Instructor': 'Weddle G'},
#  {'CRN': '75581', 'Credits': '1', 'Instructor': 'Fischer S'},
#  {'CRN': '75582', 'Credits': '1', 'Instructor': 'Fischer S'},
#  {'CRN': '75583', 'Credits': '1', 'Instructor': 'STAFF'},
#  {'CRN': '75584', 'Credits': '1', 'Instructor': 'Harper J'},
#  {'CRN': '75585', 'Credits': '1', 'Instructor': 'STAFF'},
#  {'CRN': '75586', 'Credits': '1', 'Instructor': 'STAFF'},
#  {'CRN': '75587', 'Credits': '1', 'Instructor': 'STAFF'},
#  {'CRN': '75061', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75062', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75473', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75592', 'Credits': '1', 'Instructor': 'Lloyd J'},
#  {'CRN': '75593', 'Credits': '1', 'Instructor': 'Schirmann P'},
#  {'CRN': '75594', 'Credits': '1', 'Instructor': 'Lloyd J'},
#  {'CRN': '75595', 'Credits': '1', 'Instructor': 'OÕConnell E'},
#  {'CRN': '75596', 'Credits': '1', 'Instructor': 'Schirmann P'},
#  {'CRN': '75597', 'Credits': '1', 'Instructor': 'STAFF'},
#  {'CRN': '75063', 'Credits': '3', 'Instructor': 'Kubasik M'},
#  {'CRN': '75598', 'Credits': '1', 'Instructor': 'Kubasik M'},
#  {'CRN': '76246', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76784', 'Credits': '1', 'Instructor': 'STAFF'},
#  {'CRN': '76785', 'Credits': '3', 'Instructor': 'Sauer G'},
#  {'CRN': '76786', 'Credits': '1', 'Instructor': 'STAFF'},
#  {'CRN': '75294', 'Credits': '3', 'Instructor': 'Harper-Leatherman A'},
#  {'CRN': '75348', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75349', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76773', 'Credits': '3', 'Instructor': 'Rosivach V'},
#  {'CRN': '76242', 'Credits': '3', 'Instructor': 'Ruffini G'},
#  {'CRN': '76243', 'Credits': '3', 'Instructor': 'Ruffini G'},
#  {'CRN': '75134', 'Credits': '3', 'Instructor': 'Ryan M'},
#  {'CRN': '75148', 'Credits': '3', 'Instructor': 'Brennan N'},
#  {'CRN': '75133', 'Credits': '3', 'Instructor': 'Ryan M'},
#  {'CRN': '75721', 'Credits': '3', 'Instructor': 'Brennan N'},
#  {'CRN': '75135', 'Credits': '3', 'Instructor': 'DÕAmico C'},
#  {'CRN': '75136', 'Credits': '3', 'Instructor': 'DÕAmico C'},
#  {'CRN': '75190', 'Credits': '3', 'Instructor': 'Larkin T'},
#  {'CRN': '75543', 'Credits': '3', 'Instructor': 'Smith J'},
#  {'CRN': '75544', 'Credits': '3', 'Instructor': 'Smith J'},
#  {'CRN': '76782', 'Credits': '3', 'Instructor': 'Arendt C'},
#  {'CRN': '75334', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75335', 'Credits': '3', 'Instructor': 'Duarte L'},
#  {'CRN': '76495', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75234', 'Credits': '3', 'Instructor': 'Nuru A'},
#  {'CRN': '75472', 'Credits': '3', 'Instructor': 'Ryan M'},
#  {'CRN': '75195', 'Credits': '3', 'Instructor': 'Pagano M'},
#  {'CRN': '76249', 'Credits': '3', 'Instructor': 'Gil-Egui G'},
#  {'CRN': '76759', 'Credits': '3', 'Instructor': 'Gil-Egui G'},
#  {'CRN': '76760', 'Credits': '3', 'Instructor': 'Gudelunas D'},
#  {'CRN': '76250', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75545', 'Credits': '3', 'Instructor': 'Pagano M'},
#  {'CRN': '75137', 'Credits': '3', 'Instructor': 'Wills M'},
#  {'CRN': '75138', 'Credits': '3', 'Instructor': 'Wills M'},
#  {'CRN': '75174', 'Credits': '3', 'Instructor': 'Nuru A'},
#  {'CRN': '75720', 'Credits': '3', 'Instructor': 'Nuru A'},
#  {'CRN': '76761', 'Credits': '3', 'Instructor': 'Pagano M'},
#  {'CRN': '76762', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76763', 'Credits': '3', 'Instructor': 'Gil-Egui G'},
#  {'CRN': '76254', 'Credits': '3', 'Instructor': 'Zhang Q'},
#  {'CRN': '76764', 'Credits': '3', 'Instructor': 'Wills M'},
#  {'CRN': '75142', 'Credits': '3', 'Instructor': 'Aksan A'},
#  {'CRN': '75143', 'Credits': '3', 'Instructor': 'Lane P'},
#  {'CRN': '75388', 'Credits': '3', 'Instructor': 'Aksan A'},
#  {'CRN': '75877', 'Credits': '3', 'Instructor': 'Murray T'},
#  {'CRN': '75878', 'Credits': '3', 'Instructor': 'Murray T'},
#  {'CRN': '76116', 'Credits': '3', 'Instructor': 'Murray T'},
#  {'CRN': '75141', 'Credits': '3', 'Instructor': 'Franceschi D'},
#  {'CRN': '75144', 'Credits': '3', 'Instructor': 'Franceschi D'},
#  {'CRN': '75145', 'Credits': '3', 'Instructor': 'McCloghry G'},
#  {'CRN': '75146', 'Credits': '3', 'Instructor': 'Martin T'},
#  {'CRN': '75147', 'Credits': '3', 'Instructor': 'Martin T'},
#  {'CRN': '75386', 'Credits': '3', 'Instructor': 'Martin T'},
#  {'CRN': '75387', 'Credits': '3', 'Instructor': 'McCloghry G'},
#  {'CRN': '75389', 'Credits': '3', 'Instructor': 'Shadmani H'},
#  {'CRN': '75732', 'Credits': '3', 'Instructor': 'Martin T'},
#  {'CRN': '75869', 'Credits': '3', 'Instructor': 'Shadmani H'},
#  {'CRN': '76492', 'Credits': '3', 'Instructor': 'Shadmani H'},
#  {'CRN': '76506', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76507', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76508', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76509', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76928', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76929', 'Credits': '3', 'Instructor': 'Nantz K'},
#  {'CRN': '75006', 'Credits': '3', 'Instructor': 'Nantz K'},
#  {'CRN': '75193', 'Credits': '3', 'Instructor': 'Nantz K'},
#  {'CRN': '75493', 'Credits': '1', 'Instructor': 'Nantz K'},
#  {'CRN': '75007', 'Credits': '3', 'Instructor': 'Lane P'},
#  {'CRN': '76363', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76930', 'Credits': '3', 'Instructor': 'Aksan A'},
#  {'CRN': '75008', 'Credits': '3', 'Instructor': 'Vasquez Mazariegos'},
#  {'CRN': '76931', 'Credits': '3', 'Instructor': 'Vasquez Mazariegos'},
#  {'CRN': '75494', 'Credits': '1', 'Instructor': 'Vasquez Mazariegos'},
#  {'CRN': '76932', 'Credits': '3', 'Instructor': 'Vasquez Mazariegos'},
#  {'CRN': '75281', 'Credits': '3', 'Instructor': 'Lane P'},
#  {'CRN': '75448', 'Credits': '3', 'Instructor': 'Storms S'},
#  {'CRN': '76384', 'Credits': '3', 'Instructor': 'Calderwood P'},
#  {'CRN': '75011', 'Credits': '3', 'Instructor': 'Welles-Nystrom B'},
#  {'CRN': '75249', 'Credits': '3', 'Instructor': 'Kohli W'},
#  {'CRN': '76385', 'Credits': '3', 'Instructor': 'Kohli W'},
#  {'CRN': '75013', 'Credits': '3', 'Instructor': 'Madden C'},
#  {'CRN': '75020', 'Credits': '3', 'Instructor': 'Chisum P'},
#  {'CRN': '75024', 'Credits': '3', 'Instructor': 'Bodach J'},
#  {'CRN': '75033', 'Credits': '3', 'Instructor': 'Boquet E'},
#  {'CRN': '75036', 'Credits': '3', 'Instructor': 'Marciano L'},
#  {'CRN': '75068', 'Credits': '3', 'Instructor': 'Hilts E'},
#  {'CRN': '75127', 'Credits': '3', 'Instructor': 'Marciano L'},
#  {'CRN': '75548', 'Credits': '3', 'Instructor': 'Madden C'},
#  {'CRN': '75771', 'Credits': '3', 'Instructor': 'Bodach J'},
#  {'CRN': '75012', 'Credits': '3', 'Instructor': 'Bellas G'},
#  {'CRN': '75393', 'Credits': '3', 'Instructor': 'Murphy M'},
#  {'CRN': '75014', 'Credits': '3', 'Instructor': 'Ferrara L'},
#  {'CRN': '75394', 'Credits': '3', 'Instructor': 'Barna C'},
#  {'CRN': '75015', 'Credits': '3', 'Instructor': 'Dimyan R'},
#  {'CRN': '75395', 'Credits': '3', 'Instructor': 'Krauss J'},
#  {'CRN': '75016', 'Credits': '3', 'Instructor': 'Hoover B'},
#  {'CRN': '75397', 'Credits': '3', 'Instructor': 'DeStefano M'},
#  {'CRN': '75017', 'Credits': '3', 'Instructor': 'Burlinson J'},
#  {'CRN': '75420', 'Credits': '3', 'Instructor': 'Orlando E'},
#  {'CRN': '75018', 'Credits': '3', 'Instructor': 'Chesbro J'},
#  {'CRN': '75421', 'Credits': '3', 'Instructor': 'Halloran C'},
#  {'CRN': '75019', 'Credits': '3', 'Instructor': 'Murphy M'},
#  {'CRN': '75422', 'Credits': '3', 'Instructor': 'Winslow L'},
#  {'CRN': '75021', 'Credits': '3', 'Instructor': 'Hosten C'},
#  {'CRN': '75481', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75022', 'Credits': '3', 'Instructor': 'Otfinoski S'},
#  {'CRN': '75547', 'Credits': '3', 'Instructor': 'White M'},
#  {'CRN': '75023', 'Credits': '3', 'Instructor': 'Krauss J'},
#  {'CRN': '75549', 'Credits': '3', 'Instructor': 'Scrunton J'},
#  {'CRN': '75025', 'Credits': '3', 'Instructor': 'Otfinoski S'},
#  {'CRN': '75550', 'Credits': '3', 'Instructor': 'Sweeney M'},
#  {'CRN': '75026', 'Credits': '3', 'Instructor': 'Ferrara L'},
#  {'CRN': '75551', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75027', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75552', 'Credits': '3', 'Instructor': 'Sweeney M'},
#  {'CRN': '75028', 'Credits': '3', 'Instructor': 'Bohm D'},
#  {'CRN': '75553', 'Credits': '3', 'Instructor': 'Hoover B'},
#  {'CRN': '75029', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75739', 'Credits': '3', 'Instructor': 'Whitaker E'},
#  {'CRN': '75030', 'Credits': '3', 'Instructor': 'Moliterno F'},
#  {'CRN': '75772', 'Credits': '3', 'Instructor': 'Rose K'},
#  {'CRN': '75031', 'Credits': '3', 'Instructor': 'Xie L'},
#  {'CRN': '75773', 'Credits': '3', 'Instructor': 'Halloran C'},
#  {'CRN': '75032', 'Credits': '3', 'Instructor': 'Gannett C'},
#  {'CRN': '75774', 'Credits': '3', 'Instructor': 'Dimyan R'},
#  {'CRN': '75034', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75775', 'Credits': '3', 'Instructor': 'Moliterno F'},
#  {'CRN': '75035', 'Credits': '3', 'Instructor': 'Barna C'},
#  {'CRN': '76526', 'Credits': '3', 'Instructor': 'Hosten C'},
#  {'CRN': '75069', 'Credits': '3', 'Instructor': 'White M'},
#  {'CRN': '75391', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75392', 'Credits': '3', 'Instructor': 'DeStefano M'},
#  {'CRN': '75480', 'Credits': '3', 'Instructor': 'Epstein R'},
#  {'CRN': '75554', 'Credits': '3', 'Instructor': 'Davis C'},
#  {'CRN': '76084', 'Credits': '3', 'Instructor': 'Kelley S'},
#  {'CRN': '75730', 'Credits': '3', 'Instructor': 'OÕDriscoll S'},
#  {'CRN': '76774', 'Credits': '3', 'Instructor': 'Rosivach V'},
#  {'CRN': '75819', 'Credits': '3', 'Instructor': 'Pichlikova-Burke L'},
#  {'CRN': '75546', 'Credits': '3', 'Instructor': 'Ostrow G'},
#  {'CRN': '76366', 'Credits': '3', 'Instructor': 'Lopez E'},
#  {'CRN': '76910', 'Credits': '3', 'Instructor': 'LoMonaco M'},
#  {'CRN': '76911', 'Credits': '3', 'Instructor': 'Lopez E'},
#  {'CRN': '76912', 'Credits': '3', 'Instructor': 'Petrino E'},
#  {'CRN': '75812', 'Credits': '3', 'Instructor': 'Orlando E'},
#  {'CRN': '76913', 'Credits': '3', 'Instructor': 'OÕDriscoll S'},
#  {'CRN': '76950', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76367', 'Credits': '3', 'Instructor': 'Kelley S'},
#  {'CRN': '76368', 'Credits': '3', 'Instructor': 'Kelley S'},
#  {'CRN': '75776', 'Credits': '3', 'Instructor': 'Pearson N'},
#  {'CRN': '75777', 'Credits': '3', 'Instructor': 'Pearson N'},
#  {'CRN': '76952', 'Credits': '3', 'Instructor': 'Rinaldi J'},
#  {'CRN': '76369', 'Credits': '3', 'Instructor': 'Bowen B'},
#  {'CRN': '76914', 'Credits': '3', 'Instructor': 'Epstein R'},
#  {'CRN': '76915', 'Credits': '3', 'Instructor': 'OÕDriscoll S'},
#  {'CRN': '76916', 'Credits': '3', 'Instructor': 'Petrino E'},
#  {'CRN': '76917', 'Credits': '3', 'Instructor': 'Lopez E'},
#  {'CRN': '76918', 'Credits': '3', 'Instructor': 'Bowen B'},
#  {'CRN': '76919', 'Credits': '3', 'Instructor': 'Pearson N'},
#  {'CRN': '75460', 'Credits': '3', 'Instructor': 'Orlando E'},
#  {'CRN': '76920', 'Credits': '3', 'Instructor': 'Bayers P'},
#  {'CRN': '76921', 'Credits': '3', 'Instructor': 'Garvey J'},
#  {'CRN': '75423', 'Credits': '3', 'Instructor': 'Davis C'},
#  {'CRN': '75221', 'Credits': '3', 'Instructor': 'White M'},
#  {'CRN': '75458', 'Credits': '3', 'Instructor': 'Hilts E'},
#  {'CRN': '76922', 'Credits': '3', 'Instructor': 'White M'},
#  {'CRN': '76923', 'Credits': '3', 'Instructor': 'Magas J'},
#  {'CRN': '75160', 'Credits': '3', 'Instructor': 'Bailey H'},
#  {'CRN': '76924', 'Credits': '3', 'Instructor': 'Breunig L'},
#  {'CRN': '76379', 'Credits': '3', 'Instructor': 'Xie L'},
#  {'CRN': '76925', 'Credits': '3', 'Instructor': 'Huber S'},
#  {'CRN': '75459', 'Credits': '3', 'Instructor': 'Breunig L'},
#  {'CRN': '75295', 'Credits': '3', 'Instructor': 'Chisum P'},
#  {'CRN': '76926', 'Credits': '3', 'Instructor': 'Chisum P'},
#  {'CRN': '75336', 'Credits': '3', 'Instructor': 'Sobocinski T'},
#  {'CRN': '75424', 'Credits': '3', 'Instructor': 'Xie L'},
#  {'CRN': '76927', 'Credits': '3', 'Instructor': 'Davis C'},
#  {'CRN': '75405', 'Credits': '3', 'Instructor': 'Downie D'},
#  {'CRN': '75803', 'Credits': '3', 'Instructor': 'Scalese M'},
#  {'CRN': '75802', 'Credits': '3', 'Instructor': 'Scalese M'},
#  {'CRN': '76323', 'Credits': '3', 'Instructor': 'Lerner D'},
#  {'CRN': '76866', 'Credits': '3', 'Instructor': 'Davis W'},
#  {'CRN': '76867', 'Credits': '3', 'Instructor': 'Lerner D'},
#  {'CRN': '76868', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76869', 'Credits': '3', 'Instructor': 'Lerner D'},
#  {'CRN': '75805', 'Credits': '3', 'Instructor': 'Mayzik J'},
#  {'CRN': '75807', 'Credits': '3', 'Instructor': 'Mayzik J'},
#  {'CRN': '76870', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76329', 'Credits': '3', 'Instructor': 'Cooney M'},
#  {'CRN': '75808', 'Credits': '3', 'Instructor': 'Mayzik J'},
#  {'CRN': '76871', 'Credits': '3', 'Instructor': 'Scalese M'},
#  {'CRN': '75352', 'Credits': '3', 'Instructor': 'Erotopoulos Z'},
#  {'CRN': '75353', 'Credits': '3', 'Instructor': 'Erotopoulos Z'},
#  {'CRN': '75428', 'Credits': '3', 'Instructor': 'Boyce M'},
#  {'CRN': '75738', 'Credits': '3', 'Instructor': 'Boyce M'},
#  {'CRN': '76888', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75354', 'Credits': '3', 'Instructor': 'Erotopoulos Z'},
#  {'CRN': '75355', 'Credits': '3', 'Instructor': 'Goldfield J'},
#  {'CRN': '75356', 'Credits': '3', 'Instructor': 'Goldfield J'},
#  {'CRN': '75357', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76348', 'Credits': '3', 'Instructor': 'Erotopoulos Z'},
#  {'CRN': '76889', 'Credits': '3', 'Instructor': 'Goldfield J'},
#  {'CRN': '75366', 'Credits': '3', 'Instructor': 'Wilkinson E'},
#  {'CRN': '75719', 'Credits': '3', 'Instructor': 'Wilkinson E'},
#  {'CRN': '76890', 'Credits': '3', 'Instructor': 'Wilkinson E'},
#  {'CRN': '75555', 'Credits': '3', 'Instructor': 'Rosivach V'},
#  {'CRN': '75556', 'Credits': '3', 'Instructor': 'Rosivach V'},
#  {'CRN': '76350', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75500', 'Credits': '3', 'Instructor': 'Lawrence A'},
#  {'CRN': '75501', 'Credits': '3', 'Instructor': 'Lawrence A'},
#  {'CRN': '75506', 'Credits': '3', 'Instructor': 'McFadden D'},
#  {'CRN': '75495', 'Credits': '3', 'Instructor': 'Bucki C'},
#  {'CRN': '75496', 'Credits': '3', 'Instructor': 'Li D'},
#  {'CRN': '75497', 'Credits': '3', 'Instructor': 'Keegan K'},
#  {'CRN': '75498', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75499', 'Credits': '3', 'Instructor': 'Abbott W'},
#  {'CRN': '75502', 'Credits': '3', 'Instructor': 'Abbott W'},
#  {'CRN': '75503', 'Credits': '3', 'Instructor': 'Marsans-Sakly S'},
#  {'CRN': '75504', 'Credits': '3', 'Instructor': 'Behre P'},
#  {'CRN': '75505', 'Credits': '3', 'Instructor': 'Palmer L'},
#  {'CRN': '75705', 'Credits': '3', 'Instructor': 'Russo C'},
#  {'CRN': '75794', 'Credits': '3', 'Instructor': 'Behre P'},
#  {'CRN': '75795', 'Credits': '3', 'Instructor': 'Toler H'},
#  {'CRN': '75796', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75797', 'Credits': '3', 'Instructor': 'Russo C'},
#  {'CRN': '76511', 'Credits': '3', 'Instructor': 'Yannielli J'},
#  {'CRN': '76512', 'Credits': '3', 'Instructor': 'Li D'},
#  {'CRN': '76514', 'Credits': '3', 'Instructor': 'Marsans-Sakly S'},
#  {'CRN': '76515', 'Credits': '3', 'Instructor': 'Behre P'},
#  {'CRN': '75798', 'Credits': '3', 'Instructor': 'Palmer L'},
#  {'CRN': '76256', 'Credits': '3', 'Instructor': 'Abbott W'},
#  {'CRN': '76838', 'Credits': '3', 'Instructor': 'Ruffini G'},
#  {'CRN': '76839', 'Credits': '3', 'Instructor': 'Hohl E'},
#  {'CRN': '76840', 'Credits': '3', 'Instructor': 'Hohl E'},
#  {'CRN': '75452', 'Credits': '3', 'Instructor': 'Hohl E'},
#  {'CRN': '75507', 'Credits': '3', 'Instructor': 'Hohl E'},
#  {'CRN': '76841', 'Credits': '3', 'Instructor': 'McFadden D'},
#  {'CRN': '75799', 'Credits': '3', 'Instructor': 'McFadden D'},
#  {'CRN': '76842', 'Credits': '3', 'Instructor': 'Li D'},
#  {'CRN': '76843', 'Credits': '3', 'Instructor': 'Marsans-Sakly S'},
#  {'CRN': '76844', 'Credits': '3', 'Instructor': 'Adair J'},
#  {'CRN': '76845', 'Credits': '3', 'Instructor': 'Adair J'},
#  {'CRN': '76264', 'Credits': '3', 'Instructor': 'Keegan K'},
#  {'CRN': '76846', 'Credits': '3', 'Instructor': 'Behre P'},
#  {'CRN': '76847', 'Credits': '3', 'Instructor': 'Bucki C'},
#  {'CRN': '76848', 'Credits': '3', 'Instructor': 'Adair J'},
#  {'CRN': '76849', 'Credits': '3', 'Instructor': 'McFadden D'},
#  {'CRN': '75059', 'Credits': '4', 'Instructor': 'Sealey K'},
#  {'CRN': '75162', 'Credits': '4', 'Instructor': 'Keenan D'},
#  {'CRN': '75058', 'Credits': '3', 'Instructor': 'Garvey J'},
#  {'CRN': '75179', 'Credits': '3', 'Instructor': 'Fernandez A'},
#  {'CRN': '75180', 'Credits': '3', 'Instructor': 'Gil-Egui G'},
#  {'CRN': '75194', 'Credits': '3', 'Instructor': 'Perkus A'},
#  {'CRN': '75296', 'Credits': '3', 'Instructor': 'Umansky E'},
#  {'CRN': '75060', 'Credits': '3', 'Instructor': 'Schlichting K'},
#  {'CRN': '75342', 'Credits': '3', 'Instructor': 'Jones T'},
#  {'CRN': '76775', 'Credits': '3', 'Instructor': 'Jones T'},
#  {'CRN': '75540', 'Credits': '3', 'Instructor': 'Leatherman J'},
#  {'CRN': '75343', 'Credits': '3', 'Instructor': 'Crawford D'},
#  {'CRN': '76346', 'Credits': '3', 'Instructor': 'Wilson J'},
#  {'CRN': '76776', 'Credits': '3', 'Instructor': 'Franceschi D'},
#  {'CRN': '75749', 'Credits': '3', 'Instructor': 'Poli P'},
#  {'CRN': '75158', 'Credits': '3', 'Instructor': 'Jones T'},
#  {'CRN': '75358', 'Credits': '3', 'Instructor': 'Diaz S'},
#  {'CRN': '75359', 'Credits': '3', 'Instructor': 'Eliasoph Y'},
#  {'CRN': '75360', 'Credits': '3', 'Instructor': 'Eliasoph Y'},
#  {'CRN': '75361', 'Credits': '3', 'Instructor': 'Carolan M'},
#  {'CRN': '75485', 'Credits': '3', 'Instructor': 'Diaz S'},
#  {'CRN': '75760', 'Credits': '3', 'Instructor': 'Carolan M'},
#  {'CRN': '75362', 'Credits': '3', 'Instructor': 'Morrissette J'},
#  {'CRN': '75363', 'Credits': '3', 'Instructor': 'Morrissette J'},
#  {'CRN': '75364', 'Credits': '3', 'Instructor': 'Diaz S'},
#  {'CRN': '75365', 'Credits': '3', 'Instructor': 'Diaz S'},
#  {'CRN': '75447', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75451', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76891', 'Credits': '3', 'Instructor': 'Carolan M'},
#  {'CRN': '75350', 'Credits': '3', 'Instructor': 'Avery K'},
#  {'CRN': '75351', 'Credits': '3', 'Instructor': 'Avery K'},
#  {'CRN': '75382', 'Credits': '4', 'Instructor': 'Rosivach V'},
#  {'CRN': '75383', 'Credits': '3', 'Instructor': 'Rosivach V'},
#  {'CRN': '75706', 'Credits': '3', 'Instructor': 'Cunningham P'},
#  {'CRN': '75707', 'Credits': '3', 'Instructor': 'Kaminski S'},
#  {'CRN': '76270', 'Credits': '3', 'Instructor': 'Kar S'},
#  {'CRN': '75129', 'Credits': '3', 'Instructor': 'Fang S'},
#  {'CRN': '75156', 'Credits': '3', 'Instructor': 'Romansky T'},
#  {'CRN': '75157', 'Credits': '3', 'Instructor': 'Pfeil J'},
#  {'CRN': '75427', 'Credits': '3', 'Instructor': 'Grant M'},
#  {'CRN': '75847', 'Credits': '3', 'Instructor': 'Parisi R'},
#  {'CRN': '75985', 'Credits': '3', 'Instructor': 'Lalani R'},
#  {'CRN': '76112', 'Credits': '3', 'Instructor': 'Lalani R'},
#  {'CRN': '76117', 'Credits': '3', 'Instructor': 'Romansky T'},
#  {'CRN': '76504', 'Credits': '3', 'Instructor': 'McCammon D'},
#  {'CRN': '75401', 'Credits': '3', 'Instructor': 'Dennin J'},
#  {'CRN': '75945', 'Credits': '3', 'Instructor': 'Ryan D'},
#  {'CRN': '76269', 'Credits': '3', 'Instructor': 'Rafalski S'},
#  {'CRN': '76951', 'Credits': '3', 'Instructor': 'Grant M'},
#  {'CRN': '75850', 'Credits': '3', 'Instructor': 'Weiss J'},
#  {'CRN': '75851', 'Credits': '3', 'Instructor': 'Weiss J'},
#  {'CRN': '75852', 'Credits': '3', 'Instructor': 'Cunningham P'},
#  {'CRN': '75853', 'Credits': '3', 'Instructor': 'Baginski P'},
#  {'CRN': '75854', 'Credits': '3', 'Instructor': 'Baginski P'},
#  {'CRN': '75855', 'Credits': '3', 'Instructor': 'Pfeil J'},
#  {'CRN': '75856', 'Credits': '3', 'Instructor': 'Pfeil J'},
#  {'CRN': '75857', 'Credits': '3', 'Instructor': 'Carroll L'},
#  {'CRN': '75858', 'Credits': '3', 'Instructor': 'Joannon-Bellows F'},
#  {'CRN': '75859', 'Credits': '3', 'Instructor': 'Shanazu P'},
#  {'CRN': '75861', 'Credits': '3', 'Instructor': 'Franchella M'},
#  {'CRN': '75885', 'Credits': '3', 'Instructor': 'Giegengack E'},
#  {'CRN': '75910', 'Credits': '3', 'Instructor': 'Giegengack E'},
#  {'CRN': '76104', 'Credits': '3', 'Instructor': 'Reed M'},
#  {'CRN': '76105', 'Credits': '3', 'Instructor': 'Shanazu P'},
#  {'CRN': '76829', 'Credits': '3', 'Instructor': 'Cunningham P'},
#  {'CRN': '75862', 'Credits': '3', 'Instructor': 'Staecker C'},
#  {'CRN': '75863', 'Credits': '3', 'Instructor': 'Staecker C'},
#  {'CRN': '75697', 'Credits': '4', 'Instructor': 'Ryan D'},
#  {'CRN': '75698', 'Credits': '4', 'Instructor': 'Wakin S'},
#  {'CRN': '76830', 'Credits': '4', 'Instructor': 'Sawin S'},
#  {'CRN': '76285', 'Credits': '3', 'Instructor': 'Staecker C'},
#  {'CRN': '75700', 'Credits': '4', 'Instructor': 'Coleman M'},
#  {'CRN': '75701', 'Credits': '4', 'Instructor': 'Bernhardt C'},
#  {'CRN': '75703', 'Credits': '4', 'Instructor': 'Rafalski S'},
#  {'CRN': '76505', 'Credits': '4', 'Instructor': 'Pfeil J'},
#  {'CRN': '75702', 'Credits': '4', 'Instructor': 'McSweeney L'},
#  {'CRN': '75163', 'Credits': '3', 'Instructor': 'Danaher R'},
#  {'CRN': '75164', 'Credits': '3', 'Instructor': 'Danaher R'},
#  {'CRN': '75177', 'Credits': '3', 'Instructor': 'Fang S'},
#  {'CRN': '75178', 'Credits': '3', 'Instructor': 'Fang S'},
#  {'CRN': '75209', 'Credits': '3', 'Instructor': 'Cron J'},
#  {'CRN': '75275', 'Credits': '3', 'Instructor': 'Cron J'},
#  {'CRN': '75911', 'Credits': '3', 'Instructor': 'Manning C'},
#  {'CRN': '76271', 'Credits': '3', 'Instructor': 'Manning C'},
#  {'CRN': '76454', 'Credits': '3', 'Instructor': 'Sawin S'},
#  {'CRN': '76272', 'Credits': '3', 'Instructor': 'Bernhardt C'},
#  {'CRN': '75149', 'Credits': '3', 'Instructor': 'Baginski P'},
#  {'CRN': '75864', 'Credits': '3', 'Instructor': 'Striuli J'},
#  {'CRN': '75845', 'Credits': '4', 'Instructor': 'Wakin S'},
#  {'CRN': '75846', 'Credits': '4', 'Instructor': 'Fine B'},
#  {'CRN': '76831', 'Credits': '3', 'Instructor': 'Fine B'},
#  {'CRN': '75708', 'Credits': '4', 'Instructor': 'Striuli J'},
#  {'CRN': '75235', 'Credits': '3', 'Instructor': 'Demers M'},
#  {'CRN': '75037', 'Credits': '3', 'Instructor': 'Dennin J'},
#  {'CRN': '76832', 'Credits': '3', 'Instructor': 'Striuli J'},
#  {'CRN': '75038', 'Credits': '3', 'Instructor': 'Fine B'},
#  {'CRN': '75131', 'Credits': '3', 'Instructor': 'Sawin S'},
#  {'CRN': '76833', 'Credits': '3', 'Instructor': 'Rafalski S'},
#  {'CRN': '76286', 'Credits': '3', 'Instructor': 'Bernhardt C'},
#  {'CRN': '75283', 'Credits': '3', 'Instructor': 'Murchie A'},
#  {'CRN': '75329', 'Credits': '3', 'Instructor': 'Ciavaglia M'},
#  {'CRN': '76436', 'Credits': '3', 'Instructor': 'Ciavaglia M'},
#  {'CRN': '75561', 'Credits': '3', 'Instructor': 'Cooney M'},
#  {'CRN': '75810', 'Credits': '3', 'Instructor': 'Nash L'},
#  {'CRN': '75154', 'Credits': '3', 'Instructor': 'Nash L'},
#  {'CRN': '75811', 'Credits': '3', 'Instructor': 'Cooney M'},
#  {'CRN': '75155', 'Credits': '3', 'Instructor': 'Rabin S'},
#  {'CRN': '76872', 'Credits': '3', 'Instructor': 'Murchie A'},
#  {'CRN': '76873', 'Credits': '3', 'Instructor': 'Nash L'},
#  {'CRN': '76330', 'Credits': '3', 'Instructor': 'Cooney M'},
#  {'CRN': '75075', 'Credits': '1', 'Instructor': 'Grauer J'},
#  {'CRN': '75076', 'Credits': '1', 'Instructor': 'Fumasoli J'},
#  {'CRN': '75331', 'Credits': '3', 'Instructor': 'Nash L'},
#  {'CRN': '76874', 'Credits': '3', 'Instructor': 'Nash L'},
#  {'CRN': '76875', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75512', 'Credits': '3', 'Instructor': 'Brill S'},
#  {'CRN': '75513', 'Credits': '3', 'Instructor': 'Brill S'},
#  {'CRN': '75516', 'Credits': '3', 'Instructor': 'DeWitt W'},
#  {'CRN': '75508', 'Credits': '3', 'Instructor': 'DeWitt W'},
#  {'CRN': '75509', 'Credits': '3', 'Instructor': 'Drake R'},
#  {'CRN': '75510', 'Credits': '3', 'Instructor': 'Drake R'},
#  {'CRN': '75511', 'Credits': '3', 'Instructor': 'Keenan D'},
#  {'CRN': '75514', 'Credits': '3', 'Instructor': 'Keenan D'},
#  {'CRN': '75515', 'Credits': '3', 'Instructor': 'Labinski M'},
#  {'CRN': '75517', 'Credits': '3', 'Instructor': 'Labinski M'},
#  {'CRN': '75518', 'Credits': '3', 'Instructor': 'Peduti D'},
#  {'CRN': '75520', 'Credits': '3', 'Instructor': 'Sealey K'},
#  {'CRN': '75521', 'Credits': '3', 'Instructor': 'Sealey K'},
#  {'CRN': '75522', 'Credits': '3', 'Instructor': 'Alcorn J'},
#  {'CRN': '75523', 'Credits': '3', 'Instructor': 'Alcorn J'},
#  {'CRN': '75524', 'Credits': '3', 'Instructor': 'Smith J'},
#  {'CRN': '75576', 'Credits': '3', 'Instructor': 'Smith J'},
#  {'CRN': '75731', 'Credits': '3', 'Instructor': 'Smith J'},
#  {'CRN': '75735', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75736', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75741', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75879', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75525', 'Credits': '3', 'Instructor': 'Jacob D'},
#  {'CRN': '75526', 'Credits': '3', 'Instructor': 'Jacob D'},
#  {'CRN': '75527', 'Credits': '3', 'Instructor': 'Bayne S'},
#  {'CRN': '75528', 'Credits': '3', 'Instructor': 'Bayne S'},
#  {'CRN': '76777', 'Credits': '3', 'Instructor': 'Lew G'},
#  {'CRN': '76778', 'Credits': '3', 'Instructor': 'Lew G'},
#  {'CRN': '76779', 'Credits': '3', 'Instructor': 'Brill S'},
#  {'CRN': '75529', 'Credits': '3', 'Instructor': 'Peduti D'},
#  {'CRN': '75530', 'Credits': '3', 'Instructor': 'Peduti D'},
#  {'CRN': '75531', 'Credits': '3', 'Instructor': 'Stambovsky P'},
#  {'CRN': '75767', 'Credits': '3', 'Instructor': 'Stambovsky P'},
#  {'CRN': '76780', 'Credits': '3', 'Instructor': 'Drake R'},
#  {'CRN': '75867', 'Credits': '3', 'Instructor': 'DeWitt W'},
#  {'CRN': '75768', 'Credits': '3', 'Instructor': 'Rodrigues U'},
#  {'CRN': '75769', 'Credits': '3', 'Instructor': 'Rodrigues U'},
#  {'CRN': '75532', 'Credits': '3', 'Instructor': 'Svoboda T'},
#  {'CRN': '75533', 'Credits': '3', 'Instructor': 'Svoboda T'},
#  {'CRN': '75535', 'Credits': '3', 'Instructor': 'Fernandez J'},
#  {'CRN': '75536', 'Credits': '3', 'Instructor': 'Fernandez J'},
#  {'CRN': '75537', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76281', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76803', 'Credits': '3', 'Instructor': 'Labinski M'},
#  {'CRN': '76781', 'Credits': '3', 'Instructor': 'Bayne S'},
#  {'CRN': '76804', 'Credits': '3', 'Instructor': 'Svoboda T'},
#  {'CRN': '75039', 'Credits': '3', 'Instructor': 'Biselli A'},
#  {'CRN': '75072', 'Credits': '3', 'Instructor': 'Xu M'},
#  {'CRN': '75073', 'Credits': '3', 'Instructor': 'Wojna R'},
#  {'CRN': '75151', 'Credits': '3', 'Instructor': 'Dlugos D'},
#  {'CRN': '75210', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75763', 'Credits': '3', 'Instructor': 'Winn D'},
#  {'CRN': '76806', 'Credits': '3', 'Instructor': 'Das B'},
#  {'CRN': '75605', 'Credits': '1', 'Instructor': 'Winn D'},
#  {'CRN': '75607', 'Credits': '1', 'Instructor': 'Xu M'},
#  {'CRN': '75608', 'Credits': '1', 'Instructor': 'Das B'},
#  {'CRN': '75610', 'Credits': '1', 'Instructor': 'Zeylikovich I'},
#  {'CRN': '75611', 'Credits': '1', 'Instructor': 'Kuhn J'},
#  {'CRN': '75612', 'Credits': '1', 'Instructor': 'Cavallo J'},
#  {'CRN': '75613', 'Credits': '1', 'Instructor': 'Zeylikovich I'},
#  {'CRN': '75430', 'Credits': '3', 'Instructor': 'Das B'},
#  {'CRN': '76807', 'Credits': '3', 'Instructor': 'Kuhn J'},
#  {'CRN': '75128', 'Credits': '3', 'Instructor': 'Norvell B'},
#  {'CRN': '75315', 'Credits': '3', 'Instructor': 'Norvell B'},
#  {'CRN': '76808', 'Credits': '3', 'Instructor': 'Heiden D'},
#  {'CRN': '76809', 'Credits': '3', 'Instructor': 'Winn D'},
#  {'CRN': '75399', 'Credits': '3', 'Instructor': 'Balaji U'},
#  {'CRN': '75764', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75614', 'Credits': '1', 'Instructor': 'Cavallo J'},
#  {'CRN': '75765', 'Credits': '1', 'Instructor': 'Denenberg J'},
#  {'CRN': '76810', 'Credits': '3', 'Instructor': 'Biselli A'},
#  {'CRN': '75400', 'Credits': '3', 'Instructor': 'Xu M'},
#  {'CRN': '75040', 'Credits': '3', 'Instructor': 'Biselli A'},
#  {'CRN': '75071', 'Credits': '4', 'Instructor': 'Das B'},
#  {'CRN': '75041', 'Credits': '3', 'Instructor': 'Alphonso G'},
#  {'CRN': '75429', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75227', 'Credits': '3', 'Instructor': 'Alphonso G'},
#  {'CRN': '75042', 'Credits': '3', 'Instructor': 'Patton M'},
#  {'CRN': '75542', 'Credits': '3', 'Instructor': 'Patton M'},
#  {'CRN': '75043', 'Credits': '3', 'Instructor': 'Cassidy K'},
#  {'CRN': '75541', 'Credits': '3', 'Instructor': 'Cassidy K'},
#  {'CRN': '75126', 'Credits': '3', 'Instructor': 'Cassidy K'},
#  {'CRN': '76357', 'Credits': '3', 'Instructor': 'Boryczka J'},
#  {'CRN': '75751', 'Credits': '3', 'Instructor': 'Boryczka J'},
#  {'CRN': '76855', 'Credits': '3', 'Instructor': 'Leatherman J'},
#  {'CRN': '75539', 'Credits': '3', 'Instructor': 'Leatherman J'},
#  {'CRN': '76856', 'Credits': '3', 'Instructor': 'Downie D'},
#  {'CRN': '76355', 'Credits': '3', 'Instructor': 'Downie D'},
#  {'CRN': '76859', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75865', 'Credits': '3', 'Instructor': 'Patton M'},
#  {'CRN': '76857', 'Credits': '3', 'Instructor': 'Alphonso G'},
#  {'CRN': '75044', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76887', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75345', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75470', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75045', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75046', 'Credits': '3', 'Instructor': 'Claydon J'},
#  {'CRN': '75175', 'Credits': '3', 'Instructor': 'Andreychik M'},
#  {'CRN': '76700', 'Credits': '3', 'Instructor': 'Rakowitz S'},
#  {'CRN': '75317', 'Credits': '3', 'Instructor': 'Amico M'},
#  {'CRN': '76071', 'Credits': '3', 'Instructor': 'Amico M'},
#  {'CRN': '76291', 'Credits': '3', 'Instructor': 'Creane M'},
#  {'CRN': '76070', 'Credits': '3', 'Instructor': 'Braginsky D'},
#  {'CRN': '76072', 'Credits': '4', 'Instructor': 'Salafia W'},
#  {'CRN': '76077', 'Credits': '4', 'Instructor': 'Henkel L'},
#  {'CRN': '76701', 'Credits': '4', 'Instructor': 'Salafia W'},
#  {'CRN': '76073', 'Credits': '0', 'Instructor': 'Salafia W'},
#  {'CRN': '76074', 'Credits': '0', 'Instructor': 'Salafia W'},
#  {'CRN': '76075', 'Credits': '0', 'Instructor': 'Henkel L'},
#  {'CRN': '76076', 'Credits': '0', 'Instructor': 'Henkel L'},
#  {'CRN': '76702', 'Credits': '0', 'Instructor': 'Salafia W'},
#  {'CRN': '76703', 'Credits': '0', 'Instructor': 'Salafia W'},
#  {'CRN': '76079', 'Credits': '4', 'Instructor': 'Fichtenholtz H'},
#  {'CRN': '76292', 'Credits': '4', 'Instructor': 'Andreychik M'},
#  {'CRN': '76704', 'Credits': '4', 'Instructor': 'McClure M'},
#  {'CRN': '76293', 'Credits': '3', 'Instructor': 'Rakowitz S'},
#  {'CRN': '76705', 'Credits': '3', 'Instructor': 'Creane M'},
#  {'CRN': '76083', 'Credits': '4', 'Instructor': 'Primavera J'},
#  {'CRN': '76080', 'Credits': '3', 'Instructor': 'Andreychik M'},
#  {'CRN': '76082', 'Credits': '3', 'Instructor': 'McClure M'},
#  {'CRN': '76097', 'Credits': '3', 'Instructor': 'Creane M'},
#  {'CRN': '76294', 'Credits': '3', 'Instructor': 'McClure M'},
#  {'CRN': '75049', 'Credits': '3', 'Instructor': 'Henkel L'},
#  {'CRN': '75048', 'Credits': '3', 'Instructor': 'Salafia W'},
#  {'CRN': '75220', 'Credits': '3', 'Instructor': 'Harding S'},
#  {'CRN': '76081', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76706', 'Credits': '3', 'Instructor': 'Harding S'},
#  {'CRN': '76707', 'Credits': '3', 'Instructor': 'Harding S'},
#  {'CRN': '76296', 'Credits': '3', 'Instructor': 'Braginsky D'},
#  {'CRN': '76103', 'Credits': '3', 'Instructor': 'Primavera J'},
#  {'CRN': '76708', 'Credits': '3', 'Instructor': 'Henkel L'},
#  {'CRN': '76740', 'Credits': '3', 'Instructor': 'Braginsky D'},
#  {'CRN': '76741', 'Credits': '3', 'Instructor': 'Harding S'},
#  {'CRN': '76058', 'Credits': '3', 'Instructor': 'Dallavalle N'},
#  {'CRN': '76428', 'Credits': '3', 'Instructor': 'Ciollo L'},
#  {'CRN': '76059', 'Credits': '3', 'Instructor': 'Dallavalle N'},
#  {'CRN': '76429', 'Credits': '3', 'Instructor': 'Moore S'},
#  {'CRN': '76975', 'Credits': '3', 'Instructor': 'Moore S'},
#  {'CRN': '75562', 'Credits': '3', 'Instructor': 'Slotemaker J'},
#  {'CRN': '75563', 'Credits': '3', 'Instructor': 'Slotemaker J'},
#  {'CRN': '75564', 'Credits': '3', 'Instructor': 'Nguyen M'},
#  {'CRN': '75724', 'Credits': '3', 'Instructor': 'Nguyen M'},
#  {'CRN': '75780', 'Credits': '3', 'Instructor': 'Cosacchi D'},
#  {'CRN': '75881', 'Credits': '3', 'Instructor': 'Cosacchi D'},
#  {'CRN': '76306', 'Credits': '3', 'Instructor': 'Ross S'},
#  {'CRN': '76307', 'Credits': '3', 'Instructor': 'Ross S'},
#  {'CRN': '75565', 'Credits': '3', 'Instructor': 'Thiel J'},
#  {'CRN': '75566', 'Credits': '3', 'Instructor': 'Thiel J'},
#  {'CRN': '76127', 'Credits': '3', 'Instructor': 'Thiel J'},
#  {'CRN': '76308', 'Credits': '3', 'Instructor': 'Ranstrom E'},
#  {'CRN': '76309', 'Credits': '3', 'Instructor': 'Ranstrom E'},
#  {'CRN': '75567', 'Credits': '3', 'Instructor': 'Humphrey H'},
#  {'CRN': '75568', 'Credits': '3', 'Instructor': 'Gaines J'},
#  {'CRN': '76976', 'Credits': '3', 'Instructor': 'Gaines J'},
#  {'CRN': '75571', 'Credits': '3', 'Instructor': 'Prosnit J'},
#  {'CRN': '75572', 'Credits': '3', 'Instructor': 'Umansky E'},
#  {'CRN': '76811', 'Credits': '3', 'Instructor': 'Humphrey H'},
#  {'CRN': '76812', 'Credits': '3', 'Instructor': 'Humphrey H'},
#  {'CRN': '75781', 'Credits': '3', 'Instructor': 'Thiel J'},
#  {'CRN': '76813', 'Credits': '3', 'Instructor': 'Slotemaker J'},
#  {'CRN': '75723', 'Credits': '3', 'Instructor': 'Bowler J'},
#  {'CRN': '76814', 'Credits': '3', 'Instructor': 'Spollett D'},
#  {'CRN': '76815', 'Credits': '3', 'Instructor': 'Lakeland P'},
#  {'CRN': '76816', 'Credits': '3', 'Instructor': 'Lakeland P'},
#  {'CRN': '76316', 'Credits': '3', 'Instructor': 'Sauers E'},
#  {'CRN': '76817', 'Credits': '3', 'Instructor': 'Ciollo L'},
#  {'CRN': '76818', 'Credits': '3', 'Instructor': 'Ciollo L'},
#  {'CRN': '76819', 'Credits': '3', 'Instructor': 'Davidson R'},
#  {'CRN': '76820', 'Credits': '3', 'Instructor': 'Nguyen M'},
#  {'CRN': '75346', 'Credits': '3', 'Instructor': 'Syssoeva E'},
#  {'CRN': '75347', 'Credits': '3', 'Instructor': 'Syssoeva E'},
#  {'CRN': '75050', 'Credits': '3', 'Instructor': 'Quartey B'},
#  {'CRN': '75150', 'Credits': '3', 'Instructor': 'Quartey B'},
#  {'CRN': '75754', 'Credits': '3', 'Instructor': 'Rodrigues R'},
#  {'CRN': '76510', 'Credits': '3', 'Instructor': 'Mielants E'},
#  {'CRN': '76755', 'Credits': '3', 'Instructor': 'Schlichting K'},
#  {'CRN': '75755', 'Credits': '3', 'Instructor': 'Rodrigues R'},
#  {'CRN': '75455', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75538', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75431', 'Credits': '3', 'Instructor': 'Rodrigues R'},
#  {'CRN': '75841', 'Credits': '3', 'Instructor': 'Rodrigues R'},
#  {'CRN': '75230', 'Credits': '3', 'Instructor': 'Oliver K'},
#  {'CRN': '76757', 'Credits': '4', 'Instructor': 'Schlichting K'},
#  {'CRN': '75476', 'Credits': '3', 'Instructor': 'Mielants E'},
#  {'CRN': '75477', 'Credits': '3', 'Instructor': 'Mielants E'},
#  {'CRN': '76445', 'Credits': '3', 'Instructor': 'Rodrigues R'},
#  {'CRN': '75367', 'Credits': '3', 'Instructor': 'Harshfield L'},
#  {'CRN': '75368', 'Credits': '3', 'Instructor': 'Harshfield L'},
#  {'CRN': '75369', 'Credits': '3', 'Instructor': 'Poulos C'},
#  {'CRN': '75370', 'Credits': '3', 'Instructor': 'Poulos C'},
#  {'CRN': '76518', 'Credits': '3', 'Instructor': 'Mirza G'},
#  {'CRN': '76519', 'Credits': '3', 'Instructor': 'Mirza G'},
#  {'CRN': '76892', 'Credits': '3', 'Instructor': 'Zuniga A'},
#  {'CRN': '76893', 'Credits': '3', 'Instructor': 'Zuniga A'},
#  {'CRN': '76894', 'Credits': '3', 'Instructor': 'DeLuca A'},
#  {'CRN': '76895', 'Credits': '3', 'Instructor': 'Hernandez I'},
#  {'CRN': '76896', 'Credits': '3', 'Instructor': 'Hernandez I'},
#  {'CRN': '76897', 'Credits': '3', 'Instructor': 'Lomask L'},
#  {'CRN': '76898', 'Credits': '3', 'Instructor': 'Lomask L'},
#  {'CRN': '76899', 'Credits': '3', 'Instructor': 'Arango-Martin M'},
#  {'CRN': '76900', 'Credits': '3', 'Instructor': 'Vincent M'},
#  {'CRN': '76901', 'Credits': '3', 'Instructor': 'Vincent M'},
#  {'CRN': '76902', 'Credits': '3', 'Instructor': 'Morabito P'},
#  {'CRN': '76903', 'Credits': '3', 'Instructor': 'Morabito P'},
#  {'CRN': '75372', 'Credits': '3', 'Instructor': 'Sarria M'},
#  {'CRN': '75373', 'Credits': '3', 'Instructor': 'Sarria M'},
#  {'CRN': '75374', 'Credits': '3', 'Instructor': 'Farrell M'},
#  {'CRN': '75375', 'Credits': '3', 'Instructor': 'Hernandez I'},
#  {'CRN': '75376', 'Credits': '3', 'Instructor': 'Hernandez I'},
#  {'CRN': '75377', 'Credits': '3', 'Instructor': 'Brea X'},
#  {'CRN': '75378', 'Credits': '3', 'Instructor': 'Arango-Martin M'},
#  {'CRN': '75379', 'Credits': '3', 'Instructor': 'Pavon G'},
#  {'CRN': '75380', 'Credits': '3', 'Instructor': 'Pavon G'},
#  {'CRN': '75722', 'Credits': '3', 'Instructor': 'Lomask L'},
#  {'CRN': '75761', 'Credits': '3', 'Instructor': 'Lomask L'},
#  {'CRN': '75896', 'Credits': '3', 'Instructor': 'Morriberon N'},
#  {'CRN': '76113', 'Credits': '3', 'Instructor': 'Morriberon N'},
#  {'CRN': '76455', 'Credits': '3', 'Instructor': 'Campos J'},
#  {'CRN': '76502', 'Credits': '3', 'Instructor': 'Brea X'},
#  {'CRN': '76503', 'Credits': '3', 'Instructor': 'Zabala K'},
#  {'CRN': '76984', 'Credits': '3', 'Instructor': 'Arango-Martin M'},
#  {'CRN': '75655', 'Credits': '3', 'Instructor': 'Farrell M'},
#  {'CRN': '75657', 'Credits': '3', 'Instructor': 'Campos J'},
#  {'CRN': '76904', 'Credits': '3', 'Instructor': 'Adrada Rafael S'},
#  {'CRN': '76905', 'Credits': '3', 'Instructor': 'Farrell M'},
#  {'CRN': '76906', 'Credits': '3', 'Instructor': 'Arango-Martin M'},
#  {'CRN': '76352', 'Credits': '3', 'Instructor': 'Johnson J'},
#  {'CRN': '76907', 'Credits': '3', 'Instructor': 'Adrada Rafael S'},
#  {'CRN': '76908', 'Credits': '3', 'Instructor': 'Johnson J'},
#  {'CRN': '76909', 'Credits': '3', 'Instructor': 'Campos J'},
#  {'CRN': '75171', 'Credits': '3', 'Instructor': 'Donovan M'},
#  {'CRN': '75305', 'Credits': '3', 'Instructor': 'Yarrington K'},
#  {'CRN': '75332', 'Credits': '3', 'Instructor': 'Ford K'},
#  {'CRN': '75434', 'Credits': '3', 'Instructor': 'Chamlin-Richer S'},
#  {'CRN': '76876', 'Credits': '3', 'Instructor': 'Mendelsohn J'},
#  {'CRN': '75433', 'Credits': '3', 'Instructor': 'Mendelsohn J'},
#  {'CRN': '75172', 'Credits': '3', 'Instructor': 'Chamlin-Richer S'},
#  {'CRN': '75453', 'Credits': '3', 'Instructor': 'Chamlin-Richer S'},
#  {'CRN': '75560', 'Credits': '3', 'Instructor': 'Yarrington K'},
#  {'CRN': '75173', 'Credits': '3', 'Instructor': 'Donovan M'},
#  {'CRN': '75843', 'Credits': '3', 'Instructor': 'Post J'},
#  {'CRN': '76333', 'Credits': '3', 'Instructor': 'Edwards C'},
#  {'CRN': '75309', 'Credits': '3', 'Instructor': 'Learson J'},
#  {'CRN': '75169', 'Credits': '3', 'Instructor': 'Mason J'},
#  {'CRN': '76877', 'Credits': '1', 'Instructor': 'STAFF'},
#  {'CRN': '76878', 'Credits': '1', 'Instructor': 'STAFF'},
#  {'CRN': '76879', 'Credits': '1', 'Instructor': 'LoMonaco M'},
#  {'CRN': '76880', 'Credits': '1', 'Instructor': 'STAFF'},
#  {'CRN': '76881', 'Credits': '1', 'Instructor': 'STAFF'},
#  {'CRN': '76882', 'Credits': '3', 'Instructor': 'LoMonaco M'},
#  {'CRN': '76973', 'Credits': '3', 'Instructor': 'LoMonaco M'},
#  {'CRN': '75139', 'Credits': '3', 'Instructor': 'Roth B'},
#  {'CRN': '76344', 'Credits': '3', 'Instructor': 'Jenkins J'},
#  {'CRN': '75454', 'Credits': '3', 'Instructor': 'Learson J'},
#  {'CRN': '76884', 'Credits': '3', 'Instructor': 'Porter L'},
#  {'CRN': '76885', 'Credits': '3', 'Instructor': 'Schwans T'},
#  {'CRN': '76886', 'Credits': '3', 'Instructor': 'Porter L'},
#  {'CRN': '75222', 'Credits': '3', 'Instructor': 'Bloch R'},
#  {'CRN': '75240', 'Credits': '3', 'Instructor': 'Bloch R'},
#  {'CRN': '75241', 'Credits': '3', 'Instructor': 'Coyne M'},
#  {'CRN': '75243', 'Credits': '3', 'Instructor': 'Coyne M'},
#  {'CRN': '75244', 'Credits': '3', 'Instructor': 'Coyne M'},
#  {'CRN': '75242', 'Credits': '3', 'Instructor': 'Caster P'},
#  {'CRN': '75461', 'Credits': '3', 'Instructor': 'Drusbosky J'},
#  {'CRN': '75469', 'Credits': '3', 'Instructor': 'Drusbosky J'},
#  {'CRN': '75484', 'Credits': '3', 'Instructor': 'Drusbosky J'},
#  {'CRN': '75729', 'Credits': '3', 'Instructor': 'Kardos A'},
#  {'CRN': '76101', 'Credits': '3', 'Instructor': 'Kardos A'},
#  {'CRN': '76102', 'Credits': '3', 'Instructor': 'Brenner S'},
#  {'CRN': '76689', 'Credits': '3', 'Instructor': 'Brenner S'},
#  {'CRN': '76690', 'Credits': '3', 'Instructor': 'Ebrahim A'},
#  {'CRN': '76691', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76692', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76693', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76694', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76695', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75189', 'Credits': '3', 'Instructor': 'Lee J'},
#  {'CRN': '76696', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75051', 'Credits': '3', 'Instructor': 'Peck M'},
#  {'CRN': '75052', 'Credits': '3', 'Instructor': 'Peck M'},
#  {'CRN': '76463', 'Credits': '3', 'Instructor': 'Peck M'},
#  {'CRN': '76464', 'Credits': '3', 'Instructor': 'Bloch R'},
#  {'CRN': '75316', 'Credits': '3', 'Instructor': 'Yost S'},
#  {'CRN': '75557', 'Credits': '3', 'Instructor': 'Poli P'},
#  {'CRN': '76698', 'Credits': '3', 'Instructor': 'Poli P'},
#  {'CRN': '75558', 'Credits': '3', 'Instructor': 'Ebrahim A'},
#  {'CRN': '75196', 'Credits': '3', 'Instructor': 'Ebrahim A'},
#  {'CRN': '75181', 'Credits': '3', 'Instructor': 'Caster P'},
#  {'CRN': '75789', 'Credits': '3', 'Instructor': 'Caster P'},
#  {'CRN': '75053', 'Credits': '3', 'Instructor': 'Mettler K'},
#  {'CRN': '75467', 'Credits': '3', 'Instructor': 'Spiro M'},
#  {'CRN': '75223', 'Credits': '3', 'Instructor': 'McEvoy S'},
#  {'CRN': '75290', 'Credits': '3', 'Instructor': 'McEvoy S'},
#  {'CRN': '75474', 'Credits': '3', 'Instructor': 'Hillgen-Santa J'},
#  {'CRN': '75886', 'Credits': '3', 'Instructor': 'Strauss D'},
#  {'CRN': '76390', 'Credits': '3', 'Instructor': 'Strauss D'},
#  {'CRN': '75224', 'Credits': '3', 'Instructor': 'McEvoy S'},
#  {'CRN': '75270', 'Credits': '3', 'Instructor': 'Hlawitschka W'},
#  {'CRN': '75271', 'Credits': '3', 'Instructor': 'Hlawitschka W'},
#  {'CRN': '75272', 'Credits': '3', 'Instructor': 'Jenkins J'},
#  {'CRN': '75273', 'Credits': '3', 'Instructor': 'McDonald M'},
#  {'CRN': '75274', 'Credits': '3', 'Instructor': 'McDonald M'},
#  {'CRN': '75298', 'Credits': '3', 'Instructor': 'Richardson L'},
#  {'CRN': '75727', 'Credits': '3', 'Instructor': 'Richardson L'},
#  {'CRN': '75790', 'Credits': '3', 'Instructor': 'Harrity R'},
#  {'CRN': '76851', 'Credits': '3', 'Instructor': 'Martinez V'},
#  {'CRN': '75337', 'Credits': '3', 'Instructor': 'Looby R'},
#  {'CRN': '75054', 'Credits': '3', 'Instructor': 'Zhang Y'},
#  {'CRN': '75055', 'Credits': '3', 'Instructor': 'Zhang Y'},
#  {'CRN': '76386', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76433', 'Credits': '3', 'Instructor': 'Parisi R'},
#  {'CRN': '75056', 'Credits': '3', 'Instructor': 'Alan N'},
#  {'CRN': '75132', 'Credits': '3', 'Instructor': 'Alan N'},
#  {'CRN': '75302', 'Credits': '3', 'Instructor': 'Bardos K'},
#  {'CRN': '75385', 'Credits': '3', 'Instructor': 'Martinez V'},
#  {'CRN': '76852', 'Credits': '3', 'Instructor': 'Martinez V'},
#  {'CRN': '75256', 'Credits': '3', 'Instructor': 'Koutmos G'},
#  {'CRN': '75791', 'Credits': '3', 'Instructor': 'Koutmos G'},
#  {'CRN': '76853', 'Credits': '3', 'Instructor': 'McDermott J'},
#  {'CRN': '76854', 'Credits': '3', 'Instructor': 'McDermott J'},
#  {'CRN': '76393', 'Credits': '3', 'Instructor': 'Bardos K'},
#  {'CRN': '76394', 'Credits': '3', 'Instructor': 'Bardos K'},
#  {'CRN': '75438', 'Credits': '3', 'Instructor': 'Hlawitschka W'},
#  {'CRN': '75197', 'Credits': '3', 'Instructor': 'Ozcelik Y'},
#  {'CRN': '75198', 'Credits': '3', 'Instructor': 'Ozcelik Y'},
#  {'CRN': '75199', 'Credits': '3', 'Instructor': 'Tao J'},
#  {'CRN': '75200', 'Credits': '3', 'Instructor': 'Tao J'},
#  {'CRN': '75231', 'Credits': '3', 'Instructor': 'Huntley C'},
#  {'CRN': '75246', 'Credits': '3', 'Instructor': 'Huntley C'},
#  {'CRN': '75887', 'Credits': '3', 'Instructor': 'Sklar D'},
#  {'CRN': '76469', 'Credits': '3', 'Instructor': 'Krishnamoorthy J'},
#  {'CRN': '76388', 'Credits': '3', 'Instructor': 'Huntley C'},
#  {'CRN': '75182', 'Credits': '3', 'Instructor': 'Tao J'},
#  {'CRN': '75404', 'Credits': '3', 'Instructor': 'Ozcelik Y'},
#  {'CRN': '75338', 'Credits': '3', 'Instructor': 'Ozcelik Y'},
#  {'CRN': '76389', 'Credits': '3', 'Instructor': 'Huntley C'},
#  {'CRN': '75257', 'Credits': '3', 'Instructor': 'Cavanaugh J'},
#  {'CRN': '75258', 'Credits': '3', 'Instructor': 'Cavanaugh J'},
#  {'CRN': '75259', 'Credits': '3', 'Instructor': 'Stafford L'},
#  {'CRN': '75260', 'Credits': '3', 'Instructor': 'Stafford L'},
#  {'CRN': '75314', 'Credits': '3', 'Instructor': 'Daulerio P'},
#  {'CRN': '75339', 'Credits': '3', 'Instructor': 'Cerrone R'},
#  {'CRN': '75792', 'Credits': '3', 'Instructor': 'Daulerio P'},
#  {'CRN': '76821', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76822', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75310', 'Credits': '3', 'Instructor': 'Solomon N'},
#  {'CRN': '75406', 'Credits': '3', 'Instructor': 'Solomon N'},
#  {'CRN': '75183', 'Credits': '3', 'Instructor': 'Mainiero L'},
#  {'CRN': '75225', 'Credits': '3', 'Instructor': 'Mainiero L'},
#  {'CRN': '75254', 'Credits': '3', 'Instructor': 'Bhattacharya M'},
#  {'CRN': '75255', 'Credits': '3', 'Instructor': 'Bhattacharya M'},
#  {'CRN': '75842', 'Credits': '3', 'Instructor': 'Scheraga C'},
#  {'CRN': '75299', 'Credits': '3', 'Instructor': 'Giapponi C'},
#  {'CRN': '75340', 'Credits': '3', 'Instructor': 'Giapponi C'},
#  {'CRN': '75826', 'Credits': '3', 'Instructor': 'Bhattacharya M'},
#  {'CRN': '76823', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76824', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75184', 'Credits': '3', 'Instructor': 'Baskin-Brooks J'},
#  {'CRN': '75311', 'Credits': '3', 'Instructor': 'Mainiero L'},
#  {'CRN': '75407', 'Credits': '3', 'Instructor': 'Murray D'},
#  {'CRN': '75793', 'Credits': '3', 'Instructor': 'Scheraga C'},
#  {'CRN': '75202', 'Credits': '3', 'Instructor': 'Cavanaugh J'},
#  {'CRN': '76825', 'Credits': '3', 'Instructor': 'Strauss D'},
#  {'CRN': '75341', 'Credits': '3', 'Instructor': 'Solomon N'},
#  {'CRN': '75261', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75262', 'Credits': '3', 'Instructor': 'Naderi I'},
#  {'CRN': '75263', 'Credits': '3', 'Instructor': 'Naderi I'},
#  {'CRN': '75264', 'Credits': '3', 'Instructor': 'Cavallo G'},
#  {'CRN': '75783', 'Credits': '3', 'Instructor': 'Sciandra M'},
#  {'CRN': '75785', 'Credits': '3', 'Instructor': 'Sciandra M'},
#  {'CRN': '75786', 'Credits': '3', 'Instructor': 'Bose Godbole M'},
#  {'CRN': '75787', 'Credits': '3', 'Instructor': 'Sciandra M'},
#  {'CRN': '76769', 'Credits': '3', 'Instructor': 'Bose Godbole M'},
#  {'CRN': '75232', 'Credits': '3', 'Instructor': 'Chaudhuri A'},
#  {'CRN': '75291', 'Credits': '3', 'Instructor': 'Chaudhuri A'},
#  {'CRN': '75312', 'Credits': '3', 'Instructor': 'Chaudhuri A'},
#  {'CRN': '75439', 'Credits': '3', 'Instructor': 'Cavallo G'},
#  {'CRN': '75440', 'Credits': '3', 'Instructor': 'Cavallo G'},
#  {'CRN': '75185', 'Credits': '3', 'Instructor': 'Neal J'},
#  {'CRN': '75441', 'Credits': '3', 'Instructor': 'Huetteman J'},
#  {'CRN': '75186', 'Credits': '3', 'Instructor': 'Micu C'},
#  {'CRN': '75187', 'Credits': '3', 'Instructor': 'Micu C'},
#  {'CRN': '75201', 'Credits': '3', 'Instructor': 'Rajamma R'},
#  {'CRN': '76770', 'Credits': '3', 'Instructor': 'Rajamma R'},
#  {'CRN': '76771', 'Credits': '3', 'Instructor': 'Naderi I'},
#  {'CRN': '75203', 'Credits': '3', 'Instructor': 'Neal J'},
#  {'CRN': '75464', 'Credits': '3', 'Instructor': 'Neal J'},
#  {'CRN': '75265', 'Credits': '3', 'Instructor': 'He J'},
#  {'CRN': '75266', 'Credits': '3', 'Instructor': 'He J'},
#  {'CRN': '75267', 'Credits': '3', 'Instructor': 'Lee P'},
#  {'CRN': '75268', 'Credits': '3', 'Instructor': 'Lee P'},
#  {'CRN': '75269', 'Credits': '3', 'Instructor': 'Lee P'},
#  {'CRN': '76387', 'Credits': '3', 'Instructor': 'Krishnamoorthy J'},
#  {'CRN': '76699', 'Credits': '3', 'Instructor': 'Sklar D'},
#  {'CRN': '75278', 'Credits': '3', 'Instructor': 'Munden R'},
#  {'CRN': '75848', 'Credits': '3', 'Instructor': 'Munden R'},
#  {'CRN': '76726', 'Credits': '3', 'Instructor': 'Munden R'},
#  {'CRN': '75488', 'Credits': '3', 'Instructor': 'Munden R'},
#  {'CRN': '75574', 'Credits': '3', 'Instructor': 'Waugh K'},
#  {'CRN': '76400', 'Credits': '3', 'Instructor': 'Cavallo J'},
#  {'CRN': '76710', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76711', 'Credits': '3', 'Instructor': 'Lyon D'},
#  {'CRN': '76712', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '76728', 'Credits': '3', 'Instructor': 'Govil P'},
#  {'CRN': '75161', 'Credits': '3', 'Instructor': 'Balaji U'},
#  {'CRN': '75226', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75710', 'Credits': '1', 'Instructor': 'Cavallo J'},
#  {'CRN': '75711', 'Credits': '1', 'Instructor': 'Denenberg J'},
#  {'CRN': '76125', 'Credits': '1', 'Instructor': 'Denenberg J'},
#  {'CRN': '75204', 'Credits': '3', 'Instructor': 'Balaji U'},
#  {'CRN': '75717', 'Credits': '1', 'Instructor': 'Denenberg J'},
#  {'CRN': '75205', 'Credits': '3', 'Instructor': 'Balaji U'},
#  {'CRN': '76723', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75409', 'Credits': '3', 'Instructor': 'Lopes E'},
#  {'CRN': '76724', 'Credits': '3', 'Instructor': 'Denenberg J'},
#  {'CRN': '76725', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75208', 'Credits': '3', 'Instructor': 'Srinivas Sundarram S'},
#  {'CRN': '76401', 'Credits': '3', 'Instructor': 'Srinivas Sundarram S'},
#  {'CRN': '75300', 'Credits': '3', 'Instructor': 'Zabinski M'},
#  {'CRN': '75815', 'Credits': '3', 'Instructor': 'Zabinski M'},
#  {'CRN': '76729', 'Credits': '3', 'Instructor': 'Zabinski M'},
#  {'CRN': '75713', 'Credits': '1', 'Instructor': 'Selsky G'},
#  {'CRN': '75714', 'Credits': '1', 'Instructor': 'Selsky G'},
#  {'CRN': '75744', 'Credits': '1', 'Instructor': 'Selsky G'},
#  {'CRN': '75247', 'Credits': '3', 'Instructor': 'Etemad S'},
#  {'CRN': '75064', 'Credits': '3', 'Instructor': 'STAFF'},
#  {'CRN': '75065', 'Credits': '3', 'Instructor': 'Srinivas Sundarram S'},
#  {'CRN': '76402', 'Credits': '3', 'Instructor': 'Dornfeld W'},
#  {'CRN': '76730', 'Credits': '3', 'Instructor': 'Bauer G'},
#  {'CRN': '76399', 'Credits': '3', 'Instructor': 'Gunawardana R'},
#  {'CRN': '75465', 'Credits': '3', 'Instructor': 'Judge A'},
#  {'CRN': '76731', 'Credits': '3', 'Instructor': 'Anekwe C'},
#  {'CRN': '75573', 'Credits': '3', 'Instructor': 'Etemad S'},
#  {'CRN': '75176', 'Credits': '3', 'Instructor': 'Etemad S'},
#  {'CRN': '75715', 'Credits': '1', 'Instructor': 'Wojna R'},
#  {'CRN': '75716', 'Credits': '1', 'Instructor': 'Cupic K'},
#  {'CRN': '75466', 'Credits': '3', 'Instructor': 'Lutian M'},
#  {'CRN': '75742', 'Credits': '3', 'Instructor': 'Lutian M'},
#  {'CRN': '76404', 'Credits': '3', 'Instructor': 'Craciun C'},
#  {'CRN': '75206', 'Credits': '3', 'Instructor': 'Rusu A'},
#  {'CRN': '75306', 'Credits': '3', 'Instructor': 'Rusu A'},
#  {'CRN': '75816', 'Credits': '3', 'Instructor': 'Guelakis W'},
#  {'CRN': '75817', 'Credits': '3', 'Instructor': 'LaMastra P'},
#  {'CRN': '75307', 'Credits': '3', 'Instructor': 'Rusu A'},
#  {'CRN': '75207', 'Credits': '3', 'Instructor': 'Corcoran J'},
#  {'CRN': '76734', 'Credits': '3', 'Instructor': 'Guelakis W'},
#  {'CRN': '75818', 'Credits': '3', 'Instructor': 'Govindaraja B'},
#  {'CRN': '75213', 'Credits': '3', 'Instructor': 'OÕShea E'},
#  {'CRN': '75214', 'Credits': '3', 'Instructor': 'Planas J'},
#  {'CRN': '76536', 'Credits': '3', 'Instructor': 'Murphy M'},
#  {'CRN': '75252', 'Credits': '3', 'Instructor': 'Pomarico C'},
#  {'CRN': '75577', 'Credits': '4', 'Instructor': 'Kris A'},
#  {'CRN': '75606', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75609', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75615', 'Credits': '0', 'Instructor': 'Saracino K'},
#  {'CRN': '75616', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '76738', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75215', 'Credits': '4', 'Instructor': 'Planas J'},
#  {'CRN': '76739', 'Credits': '4', 'Instructor': 'STAFF'},
#  {'CRN': '75823', 'Credits': '4', 'Instructor': 'Lovanio K'},
#  {'CRN': '75648', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75649', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75651', 'Credits': '0', 'Instructor': 'Saracino K'},
#  {'CRN': '75652', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75654', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75656', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75658', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75659', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75660', 'Credits': '0', 'Instructor': 'STAFF'},
#  {'CRN': '75661', 'Credits': '0', 'Instructor': 'Saracino K'},
#  {'CRN': '75820', 'Credits': '0', 'Instructor': 'Saracino K'},
#  ...]

# %%
course_specs_len = len(course_specs)-1

# Create new list named coursetag_list based on COURSETAG(-TagID-, Tags, -CourseOfferingID-)
coursetag_list = []

for i in range(0, course_specs_len):
    d = {};
    
    cs = course_specs[i]
    
    tags = cs['Tags']

    d['Tags'] = tags

    if(d not in coursetag_list):
        coursetag_list.append(d);

# %% [markdown]
# ## 5. (4 points)  Convert your lists to DataFrames.
# Again, that's one DataFrame per list of dicts. Name the DataFrames to match the table names. Use One cell per DataFrame and display the table at the bottom of the cell.

# %%
#create Course dataframe
course_df = pd.DataFrame(course_list)
course_df
# Out:
#      CatalogID Section                           Title
# 0       AS0200       A       Roots of American Culture
# 1       AS0400      01    Critical Issues/Amer Studies
# 2       AS0488      01    Frontier in American Culture
# 3     ASEN0490      01    Contemporary American Memoir
# 4       AY0010     C01    Intro to Four-Field Anthropo
# 5       AY0010     C02    Intro to Four-Field Anthropo
# 6       AY0052       A   Culture and Political Economy
# 7       AY0052       B   Culture and Political Economy
# 8       AY0110       A         Biological Anthropology
# 9       AY0111       A           Cultural Anthropology
# 10      AY0111       B           Cultural Anthropology
# 11      AY0115       A         Biomedical Anthropology
# 12      AY0152       A    Islamic Societies & Cultures
# 13      AY0168       A   Women & Men: Anthro of Gender
# 14      AE0262       A        Ethics and the Community
# 15      AE0265       A             Ethics in Education
# 16      AE0276       A  Ethical DimensGlobal BusPolicy
# 17      AE0281       A        Ethics of Communications
# 18      AE0284       A            Environmental Ethics
# 19      AE0284       B            Environmental Ethics
# 20      AE0285       A           Ethics of Health Care
# 21      AE0291       A                 Business Ethics
# 22      AE0291       B                 Business Ethics
# 23      AE0291       C                 Business Ethics
# 24      AE0291       D                 Business Ethics
# 25      AE0291       E                 Business Ethics
# 26      AE0291       F                 Business Ethics
# 27      AE0291       G                 Business Ethics
# 28      AR0110       A             Elementary Arabic I
# 29      AR0210       A           Intermediate Arabic I
# ...        ...     ...                             ...
# 1036   NS0312C       D  Medl Surgical Nursing I Clinic
# 1037   NS0312C       E  Medl Surgical Nursing I Clinic
# 1038   NS0312C       F  Medl Surgical Nursing I Clinic
# 1039    NS0314       A    Maternal and Newborn Nursing
# 1040   NS0314C       A   Maternal/Newborn Nursing Clin
# 1041   NS0314C       B   Maternal/Newborn Nursing Clin
# 1042   NS0314C       C   Maternal/Newborn Nursing Clin
# 1043   NS0314C       D   Maternal/Newborn Nursing Clin
# 1044   NS0314C       E   Maternal/Newborn Nursing Clin
# 1045    NS0323       A               Pediatric Nursing
# 1046   NS0323C       A      Pediatric Nursing Clinical
# 1047   NS0323C       B      Pediatric Nursing Clinical
# 1048   NS0323C       C      Pediatric Nursing Clinical
# 1049   NS0323C       D      Pediatric Nursing Clinical
# 1050   NS0323C       E      Pediatric Nursing Clinical
# 1051   NS0323C       F      Pediatric Nursing Clinical
# 1052   NS0323C       G      Pediatric Nursing Clinical
# 1053    NS0325       A     Medical Surgical Nursing II
# 1054    NS0325       B     Medical Surgical Nursing II
# 1055   NS0325C       A  Med Surgical Nursing II Clinic
# 1056   NS0325C       B  Med Surgical Nursing II Clinic
# 1057   NS0325C       C  Med Surgical Nursing II Clinic
# 1058   NS0325C       D  Med Surgical Nursing II Clinic
# 1059   NS0325C       E  Med Surgical Nursing II Clinic
# 1060   NS0325C       F  Med Surgical Nursing II Clinic
# 1061   NS0325C       G  Med Surgical Nursing II Clinic
# 1062   NS0325C       H  Med Surgical Nursing II Clinic
# 1063    NS0330       A   Comm,Pub & Globl Hlth Nursing
# 1064   NS0330C       A     CommPub&GlblHlthNsCllinical
# 1065   NS0330C       B     CommPub&GlblHlthNsCllinical
#
# [1066 rows x 3 columns]

# %%
#create coursetime Dataframe
coursetime_df = pd.DataFrame(coursetime_list)
coursetime_df
# Out:
#                            Timecodes
# 0                   [MR 0930-1045am]
# 1                    [W 0630-0830pm]
# 2                    [M 0630-0830pm]
# 3                    [T 0545-0745pm]
# 4                   [TF 1230-0145pm]
# 5                   [TF 1100-1215pm]
# 6                   [TR 0630-0745pm]
# 7                    [M 0630-0900pm]
# 8                   [MR 1230-0145pm]
# 9                   [TF 0200-0315pm]
# 10                   [T 0630-0900pm]
# 11                  [TF 0330-0445pm]
# 12                   [W 0200-0430pm]
# 13                  [TR 0500-0615pm]
# 14                  [WF 0800-0915am]
# 15                   [R 0630-0900pm]
# 16                  [MW 0500-0615pm]
# 17                  [MR 0800-0915am]
# 18                          [Online]
# 19                   [W 0630-0900pm]
# 20                   [W 1100-0130pm]
# 21                  [MW 0300-0445pm]
# 22                  [MW 0500-0645pm]
# 23                   [W 0100-0200pm]
# 24   [MR 1230-0120pm, W 1200-1250pm]
# 25                  [TF 0930-1045am]
# 26                 [TWF 1100-1150am]
# 27   [TF 1230-0120pm, W 0100-0150pm]
# 28                  [MR 1100-1215pm]
# 29                  [MR 0330-0445pm]
# ..                               ...
# 183                  [W 0700-0200pm]
# 184                 [TF 0200-0500pm]
# 185                  [T 0800-0300pm]
# 186                  [F 0800-0300pm]
# 187                  [W 0800-0300pm]
# 188                  [M 0800-0300pm]
# 189                  [R 0800-0300pm]
# 190                 [TF 0945-1245pm]
# 191                  [R 0200-0900pm]
# 192                  [R 0700-0200pm]
# 193                  [S 0700-0200pm]
# 194                  [W 0330-0445pm]
# 195                 [TR 0800-0950am]
# 196                 [MW 1000-1150am]
# 197                 [TR 1000-1150am]
# 198                 [MR 0600-0750pm]
# 199                 [MR 0330-0520pm]
# 200                 [MW 0800-0950am]
# 201                 [MR 1200-0150pm]
# 202                  [W 0500-0730pm]
# 203                 [TF 1055-0155pm]
# 204                  [M 0700-0200pm]
# 205                  [W 1230-0730pm]
# 206                  [R 0100-0800pm]
# 207                  [T 0700-0100pm]
# 208                  [W 0700-0100pm]
# 209                  [F 0700-0100pm]
# 210                  [T 0100-0800pm]
# 211                  [W 0530-0800pm]
# 212                  [W 0800-0430pm]
#
# [213 rows x 1 columns]

# %%
# create course_offering dataframe
course_offering_df = pd.DataFrame(course_offering_list)
course_offering_df['CourseID'] = course_df.index

course_offering_df
# Out:
#         CRN Credits       Instructor  CourseID
# 0     76407       3         Bayers P         0
# 1     76513       3         Garvey J         1
# 2     76934       3         Bayers P         2
# 3     76935       3          Lopez E         3
# 4     75478       3           Lacy S         4
# 5     75479       3           Lacy S         5
# 6     75752       3       Crawford D         6
# 7     76300       3         Wilson J         7
# 8     75297       3         Wilson J         8
# 9     75728       3       Crawford D         9
# 10    76753       3        Wessler S        10
# 11    76758       3        Aronsen G        11
# 12    76303       3       Crawford D        12
# 13    76754       3        Wessler S        13
# 14    75333       3         Liftig R        14
# 15    75233       3         Liftig R        15
# 16    75282       3            Day R        16
# 17    76234       3         Butler B        17
# 18    76826       3          Brown D        18
# 19    75125       3          Brown D        19
# 20    75001       3            STAFF        20
# 21    75002       3        Schmidt D        21
# 22    75003       3  Sticca-Conrod L        22
# 23    75070       3  Sticca-Conrod L        23
# 24    75308       3      Ventrella S        24
# 25    75313       3          Yoder J        25
# 26    76827       3        Schmidt N        26
# 27    76828       3        Schmidt D        27
# 28    75344       3          Douda A        28
# 29    75402       3          Douda A        29
# ...     ...     ...              ...       ...
# 1036  75838       0            STAFF      1036
# 1037  75839       0            STAFF      1037
# 1038  76062       0            STAFF      1038
# 1039  75384       4      LoGiudice J      1039
# 1040  75630       0       Manister N      1040
# 1041  75631       0       Manister N      1041
# 1042  75632       0        Burrows K      1042
# 1043  75709       0            STAFF      1043
# 1044  76751       0      LoGiudice J      1044
# 1045  75237       4         OÕShea E      1045
# 1046  75633       0          Roney L      1046
# 1047  75634       0            STAFF      1047
# 1048  75635       0            STAFF      1048
# 1049  75636       0            STAFF      1049
# 1050  75637       0            STAFF      1050
# 1051  75832       0            STAFF      1051
# 1052  75833       0          Roney L      1052
# 1053  75238       5        Chaplik S      1053
# 1054  75239       5         Sumpio C      1054
# 1055  75638       0   Iannino-Renz R      1055
# 1056  75639       0   Iannino-Renz R      1056
# 1057  75640       0            STAFF      1057
# 1058  75641       0         Bartos S      1058
# 1059  75642       0            STAFF      1059
# 1060  75643       0            STAFF      1060
# 1061  75644       0            STAFF      1061
# 1062  75645       0            STAFF      1062
# 1063  75396       4          Mager D      1063
# 1064  75676       0            STAFF      1064
# 1065  75678       0            STAFF      1065
#
# [1066 rows x 4 columns]

# %%
#create coursetag dataframe
coursetag_df = pd.DataFrame(coursetag_list)
coursetag_df
# Out:
#                               Tags
# 0                               []
# 1                  [By Permission]
# 2                    [CRNST, WDiv]
# 3                           [WDiv]
# 4                  [WDiv, ResColl]
# 5                          [USDiv]
# 6                          [CRNST]
# 7                          [JUHAN]
# 8                        [ResColl]
# 9                          [Water]
# 10                [ResColl, Water]
# 11                       [NS Only]
# 12                  [English Core]
# 13                  [History Core]
# 14                   [USDiv, SerL]
# 15                          [SerL]
# 16                  [CRNST, Water]
# 17                  [USDiv, Water]
# 18                  [WDiv, Hybrid]
# 19             [ResColl, SerL Opt]
# 20          [USDiv, ResColl, SerL]
# 21                [USDiv, ResColl]
# 22                   [WDiv, JUHAN]
# 23  [WDiv, JUHAN, Water, SerL Opt]
# 24    [WDiv, ResColl, JUHAN, SerL]
# 25               [USDiv, SerL Opt]
# 26                [ResColl, JUHAN]
# 27                   [USDiv, RNNU]
# 28                          [SDNU]
# 29                          [RNNU]
# 30                    [WDiv, RNNU]
# 31                    [SerL, RNNU]
# 32   [SerL, RNNU, Nicaragua, Jan.]

# %% [markdown]
# ## 6. (6 points) Write your DataFrames to the database.
# * Use the [DataFrame.to_sql() method](https://pandas.pydata.org/pandas-docs/stable/io.html#sql-queries) to write to the database. You will need to set the `if_exists` and (possibly) the `index` arguments when calling `.to_sql()`.
# * You will also need a sqlite3 connection.
# * A few relevant examples were given towards the end in the SQLite DDL and Migration Demo.
# * Provide a SQL SELECT query that joins your tables.

# %%
# Change datatype of two tables to string
coursetime_df['Timecodes'] = coursetime_df['Timecodes'].astype('str')
coursetag_df['Tags'] = coursetag_df['Tags'].astype('str')

# %%
conn = sqlite3.connect('FairfieldCoursesFall2017.db') # Create a database connection
#write data to COURSE table
course_df.to_sql("COURSE",conn,if_exists="append", index=False)
#write data to COURSETIME table
coursetime_df.to_sql("COURSETIME",conn,if_exists="append", index=False)
#write data to COURSE_OFFERING table
course_offering_df.to_sql("COURSE_OFFERING",conn,if_exists="append", index=False)
#write data to COURSETAG table
coursetag_df.to_sql("COURSETAG",conn,if_exists="append", index=False)

# %%
# %%sql
# select *
# FROM COURSE JOIN COURSE_OFFERING USING (CourseID) JOIN COURSETIME USING (TimeID)
#     JOIN COURSETAG USING (CourseOfferingID)
# Out:
# Done.
# []

# %% [markdown]
# ## 7. (1 point) Turn your work to GitHub.
# Commit your work in Git, then push your changes to GitHub.
